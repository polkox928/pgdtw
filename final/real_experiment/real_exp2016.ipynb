# %%
# imports
import libdtw as lib
from datetime import datetime
import pickle
import matplotlib.pyplot as plt
from matplotlib.dates import date2num
import numpy as np
from collections import defaultdict
from tqdm import tqdm
from copy import copy, deepcopy
import os
from model import *
from IPython.display import clear_output
import pandas as pd
# Out:
# C:\Users\DEPAGRA\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# The first step in the realization of the experiment is to select a meaningful time frame. First we plot the length of all the available batches against the starting date to check for any time trend.

# %%
raw_data = lib.load_data(n_to_keep=1000)
_ = raw_data.pop('reference')
plt.hist([len(v[0]['values']) for k, v in raw_data.items()])
plt.title('Distribution of batch duration')
plt.xlabel('Batch duration (min)')
plt.ylabel('Count')
plt.show()
print("Min duration: %d\nMax duration %d"\
      %(min([len(v[0]['values']) for k, v in raw_data.items()]), max([len(v[0]['values']) for k, v in raw_data.items()])))
# Out:
# Min duration: 146
# Max duration 1661

# %%
fig = plt.figure(figsize=(15,7))
for k, v in raw_data.items():
    plt.plot_date(date2num(datetime.strptime(v[0]['start'], '%Y-%m-%d %H:%M:%S')), len(v[0]['values']), color = '#d90000')
plt.xlabel('Start date', fontsize = 14)
plt.ylabel('Batch duration', fontsize = 14)
plt.title('Batch duration against Start date', fontsize = 16)
plt.xlim((date2num(datetime.strptime('2014-11-01', '%Y-%m-%d')), 
          date2num(datetime.strptime('2017-12-31', '%Y-%m-%d'))))

plt.axvspan(date2num(datetime.strptime('2014-11-01', '%Y-%m-%d')), 
            date2num(datetime.strptime('2014-12-31', '%Y-%m-%d')), 
            color='#d2d2d2', alpha=0.1)

plt.axvspan(date2num(datetime.strptime('2015-01-01', '%Y-%m-%d')), 
            date2num(datetime.strptime('2015-12-31', '%Y-%m-%d')), 
            color='#d2d2d2', alpha=0.5)

plt.axvspan(date2num(datetime.strptime('2016-01-01', '%Y-%m-%d')), 
            date2num(datetime.strptime('2016-12-31', '%Y-%m-%d')), 
            color='#d2d2d2', alpha=0.1)

plt.axvspan(date2num(datetime.strptime('2017-01-01', '%Y-%m-%d')), 
            date2num(datetime.strptime('2017-12-31', '%Y-%m-%d')), 
            color='#d2d2d2', alpha=0.5)
plt.savefig('durVSstart.png')
plt.show()

# %% [markdown]
# The data seems to have a time dependency. This could be useful for the predictive model, but it's unrealistic to use all the data available for the DTW part of the system. Therefore we select only one period, the 2016, and remove the outlier batches: this way DTW will perform better and we will have a wider search space for the step patterns.

# %%
fig, (ax0, ax1) = plt.subplots(1,2, figsize=(15,5), gridspec_kw = {'width_ratios':[3, 1]})
data_2016 = dict((k, v) for k, v in raw_data.items() if datetime.strptime(v[0]['start'][:4], '%Y') == datetime.strptime('2016', '%Y'))
for k, v in data_2016.items():
    ax0.plot_date(date2num(datetime.strptime(v[0]['start'], '%Y-%m-%d %H:%M:%S')), len(v[0]['values']), color = '#000000')
ax0.set_xlabel('Start date')
ax0.set_ylabel('Batch duration')
ax0.set_title('Batch duration against Start date')

box = ax1.boxplot([len(v[0]['values']) for k, v in data_2016.items()])
ax1.set_ylabel('Batch duration')
plt.setp(ax1, xticklabels=['2016'])
plt.show()

upper_cap = box['caps'][1].get_ydata()[0]
print('Upper cap value: %d'%upper_cap)
# Out:
# Upper cap value: 708

# %% [markdown]
# Batches with duration above 708 minutes are considered outliers. We remove them from the dataset.

# %%
data = dict((k,v) for k,v in data_2016.items() if len(v[0]['values']) <= 708)

fig, (ax0, ax1) = plt.subplots(1,2, figsize=(15,5))
for k, v in data.items():
    ax0.plot_date(date2num(datetime.strptime(v[0]['start'], '%Y-%m-%d %H:%M:%S')), len(v[0]['values']), color = '#000000')
ax0.set_xlabel('Start date')
ax0.set_ylabel('Batch duration')
ax0.set_title('Batch duration against Start date')

ax1.hist([len(v[0]['values']) for k, v in data.items()])
ax1.set_xlabel('Batch duration')
ax1.set_ylabel('Count')
ax1.set_title('Distribution of batch duration')
plt.show()

print('Number of batches: %d'%len(data))
# Out:
# Number of batches: 151

# %% [markdown]
# We have 151 batches. We use the first 101 as training set, and the other 50 as test. The IDs are assigned in temporal order, so we can use them as splitting criterion.

# %%
train_size = 101
train_data = dict(sorted(list(data.items()))[:train_size])
raw_test_data = dict(sorted(list(data.items()))[train_size:])
print("Train data: %d batches\nTest data: %d batches"%(len(train_data), len(raw_test_data)))
# Out:
# Train data: 101 batches
# Test data: 50 batches

# %% [markdown]
# We now create the DTW object for the training data, checking the maximum P value allowed for the step pattern. We seelect the batch with the median length as reference one.

# %%
if 'reference' in train_data: _=train_data.pop('reference')
train_data = lib.assign_ref(train_data)
D = lib.Dtw(json_obj=train_data)
print('Number of PVs used : %d'%len(D.pv_names))
# Out:
# Number of PVs used : 33

# %% [markdown]
# Among the 100 queriy batches, only one does not have all the PVs contained in the reference one. We therefore have 1 reference and 99 queries. We have to check if all the test batches have all the necessary PVs.

# %%
pv_ref = D.pv_names
test_data = dict()
for k, v in raw_test_data.items():
    batch = list(filter(lambda x: x['name'] in pv_ref, v))
    if len(batch) == len(pv_ref):
        test_data[k]=batch
print('Number of test batches after filtering for PVs: %d'%len(test_data))
# Out:
# Number of test batches after filtering for PVs: 50

# %% [markdown]
# All of the test batches have the required PVs

# %% [markdown]
# Let's check the maximum P value allowed

# %%
print('Global P max: %d'%D.get_global_p_max())
# Out:
# Global P max: 1

# %% [markdown]
# The maximum allowed value is P = 1. Therefore for the step pattern selection we will consider the step patterns `symmetricP05` and `symmetricP1`, and maybe also `symmetric1` and `symmetric2`.
#
# First step is to optimize the features' weights given this dataset.

# %%
num_queries = D.data['num_queries']
step_pattern = 'symmetric2'
file_path = 'data/optWeights.pickle'
n_jobs=-2
try:
    with open(file_path, 'rb') as f:
        D.data['feat_weights'] = pickle.load(f)
    #print('Initial weights:\n', D.data['feat_weights'])
except OSError as ex:
#    pass
#finally:
    D.optimize_weights(step_pattern, n_steps = 20, file_path = file_path, n_jobs=n_jobs)
    with open(file_path, 'wb') as f:
        pickle.dump(D.data['feat_weights'], f, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# Let's set the variables weights of the original DTW object with the new optimized weights

# %%
sorted(list(D.get_weight_variables().items()), key = lambda x: x[1], reverse=True)
# Out:
# [('ba_TCzWpXo', 3.2231621945076925),
#  ('ba_TCfg3Yxn', 3.221614529955474),
#  ('ba_PLAu1m2', 1.6911678668671668),
#  ('ba_FC3BnZ', 1.3435038209030385),
#  ('ba_TZHx41ABpBbhN', 1.3426510388255273),
#  ('ba_TCyNE8Mdv', 1.3310743700255487),
#  ('ba_TDZV2zDOrmiYP', 1.219830709431491),
#  ('ba_TDZyHMh1UZ', 1.1984956645804208),
#  ('ba_TZWZNzFFdHb', 1.1938101570561284),
#  ('ba_FCGUglDXyPKrnk38', 1.1675047951226567),
#  ('ba_PCLAMr1nuoSiAr', 1.0468981462066496),
#  ('ba_PCSTgdwK3V', 0.9964977921080833),
#  ('ba_PCPUSq5ah', 0.9160370462879545),
#  ('ba_FCDvhG4', 0.8591861915869534),
#  ('ba_TCkwAse0bopy8zp6', 0.8402901972310711),
#  ('ba_TC06nRC', 0.8339192662684214),
#  ('ba_TZv9w2dOu', 0.82387642561287),
#  ('ba_TZIm086h', 0.8026973178251918),
#  ('ba_PCGd0srEZp', 0.7401844519898652),
#  ('ba_TIJSj', 0.7060735054691898),
#  ('ba_ErguU', 0.6884786616870558),
#  ('ba_FQVzNY', 0.6157197009664962),
#  ('ba_FQ2Qyx', 0.6067029303109742),
#  ('ba_FQnZKYLSO02xLf', 0.5937279762873314),
#  ('ba_FIhgSwHD', 0.5923625274413772),
#  ('ba_TrWfpiPrs', 0.5774110301472146),
#  ('ba_SinhbKA', 0.5647529852113228),
#  ('ba_FCobtZJfb5TG', 0.5627732756440307),
#  ('ba_TZNCmUn29mO', 0.5550326173137785),
#  ('ba_PCG6Z9', 0.5466359771507334),
#  ('ba_FQNOJG', 0.5423644115448256),
#  ('ba_FQYXdr6Q0', 0.5420597030694593),
#  ('ba_FmYOrhonkk', 0.5135027153640023)]

# %% [markdown]
# Now it's time to select a step pattern

# %%
print('P max: %d'%D.get_global_p_max())
POSSIBLE_STEP_PATTERNS = ['symmetric2', 'symmetricP05'] + ['symmetricP%s'%p for p in np.arange(1, D.get_global_p_max()+1)]
try:
    with open('stepPattern.pickle', 'rb') as f:
        D = pickle.load(f)
except: pass

RES = defaultdict(list)
for step_pattern in POSSIBLE_STEP_PATTERNS[::-1]:
    #print(step_pattern)
    for _id in tqdm(D.data['queriesID'], desc=step_pattern, leave=False):
        D.call_dtw(_id, step_pattern=step_pattern, n_jobs=-1)

    RES[step_pattern].append(D.avg_time_distortion(step_pattern))
    RES[step_pattern].append(D.avg_distance(step_pattern))

    # pickle D object
with open('stepPattern.pickle', 'wb') as f:
    pickle.dump(D, f, protocol=pickle.HIGHEST_PROTOCOL)

TD = [x[0] for x in RES.values()]
RANGE_TD = min(TD), max(TD)

DIST = [x[1] for x in RES.values()]

RANGE_DIST = min(DIST), max(DIST)

RES_SCALED = defaultdict(list)
for step_pattern in POSSIBLE_STEP_PATTERNS:
    RES_SCALED[step_pattern] = [(RES[step_pattern][0] - RANGE_TD[0])/(RANGE_TD[1]-RANGE_TD[0])]
    RES_SCALED[step_pattern].append((RES[step_pattern][1] - RANGE_DIST[0])/(RANGE_DIST[1]-RANGE_DIST[0]))

DISTORTIONS = [RES_SCALED[step_pattern][0] for step_pattern in POSSIBLE_STEP_PATTERNS]
DISTANCES = [RES_SCALED[step_pattern][1] for step_pattern in POSSIBLE_STEP_PATTERNS]
SCORE = [np.sqrt(x**2 + y**2) for x, y in zip(DISTANCES, DISTORTIONS)]

#print(TD)
#print(DIST)

for step_pattern in POSSIBLE_STEP_PATTERNS:
    score = np.sqrt(RES_SCALED[step_pattern][0]**2 + RES_SCALED[step_pattern][1]**2)
    print('%s Score: %0.5f\tTime Dist: %0.5f/%0.5f\t DTW Dist: %0.5f/%0.5f'%(step_pattern, score, RES[step_pattern][0], 
                                                                             RES_SCALED[step_pattern][0], RES[step_pattern][1], 
                                                                             RES_SCALED[step_pattern][1]))
# Out:
# P max: 1
# symmetric2 Score: 1.00000	Time Dist: 106.14141/1.00000	 DTW Dist: 181.13020/0.00000
# symmetricP05 Score: 0.67495	Time Dist: 86.18182/0.00000	 DTW Dist: 181.27823/0.67495
# symmetricP1 Score: 1.00000	Time Dist: 86.18182/0.00000	 DTW Dist: 181.34951/1.00000

# %%
X = np.arange(1, len(SCORE)+1)

FIG = plt.figure(figsize=(12, 5))
FIG.add_subplot(1, 2, 1)

plt.plot(X, SCORE, '-o', color = '#d90000')
plt.xticks(X, POSSIBLE_STEP_PATTERNS, rotation=0)
plt.ylabel("Alignment SCORE")


FIG.add_subplot(1, 2, 2)
plt.plot(DISTANCES, DISTORTIONS, '-o', color = '#d90000')
plt.xlabel("Scaled distance")
plt.ylabel("Scaled time distortion")

for i in range(len(POSSIBLE_STEP_PATTERNS)):
    plt.annotate(POSSIBLE_STEP_PATTERNS[i][:3]+POSSIBLE_STEP_PATTERNS[i].split('c')[1], xy=(DISTANCES[i], DISTORTIONS[i]), xytext=(4, 4), textcoords='offset pixels')
plt.xlim((-0.05, 1.15))
plt.tight_layout()
plt.show()

# %%
step_pattern = 'symmetricP05'

# %%
try:
    with open('open_ended.pickle', 'rb') as f:
        D = pickle.load(f)
except:
    for _id in tqdm(D.data['queriesID'], desc='Open-ended DTW - Train Set', leave=False):
        D.call_dtw(_id, step_pattern=step_pattern, n_jobs=1, open_ended=True, all_sub_seq=True)

# %%
with open('open_ended.pickle', 'wb') as f:
    pickle.dump(D, f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
def predict_single_batch(batch, D_train):
    test_batch_id = list(batch.keys())[0]
    if '%s.csv'%test_batch_id in os.listdir('cv_onlineRF/'): return
    
    D = deepcopy(D_train)
    D.add_query(batch)
    clear_output()
    D.call_dtw(test_batch_id, step_pattern=step_pattern, n_jobs=1, open_ended=True, all_sub_seq=True)
    
    estimator = Estimator(dtw_obj=D, regressor=RandomForestRegressor())
    for (i, j, d) in tqdm(D.data_open_ended['warp_dist'][test_batch_id], desc='Predicting Batch %s'%test_batch_id):

        data_x, data_y = deepcopy(generate_dataset_xy(i, j, test_batch_id, D, data))

        train_id = data_x.loc[data_x.index != test_batch_id, :].index
        test_id = data_x.loc[data_x.index == test_batch_id, :].index

        train_loc = list()
        for _id in train_id.unique():
            locs = data_x.index.get_loc(_id)
            if type(locs) == slice:
                start, stop = locs.start, locs.stop
                train_loc.extend([[loc] for loc in np.arange(start, stop)])
            elif type(locs) == int or type(locs) == np.int64:
                train_loc.append([locs])
            else: print('\n', locs, type(locs))

        if type(data_x.index.get_loc(test_batch_id)) == slice:
            locs = data_x.index.get_loc(test_batch_id)
            start, stop = locs.start, locs.stop
            test_loc = [[loc] for loc in np.arange(start, stop)]
        elif type(data_x.index.get_loc(test_batch_id)) == int or type(data_x.index.get_loc(test_batch_id)) == np.int64:
            test_loc = [data_x.index.get_loc(test_batch_id)]
        else: print('ERROR 2')

        train_id, test_id, train_loc, test_loc = train_id.unique(), test_id.unique(), train_loc, test_loc
        if len(train_id) < 2:
            continue

        x_train = data_x.loc[train_id, :]

        y_train = np.array(np.concatenate([data_y[idx] for idx in train_loc], axis=0), dtype = [('status', bool), ('time_remaining', 'f8')])

        x_test = data_x.loc[test_id, :]
        y_test_raw = [data_y[idx] for idx in test_loc]

        y_test = np.concatenate(y_test_raw, axis=0) if len(y_test_raw)>1 else y_test_raw
        y_test = np.array(y_test, dtype = [('status', bool), ('time_remaining', 'f8')])

        estimator.fit(x_train, y_train)
        y_pred = estimator.predict(x_test)
        with open('cv_onlineRF/%s.csv'%test_id.values[0], 'a+') as f:
            for (_id, row), y_p in zip(x_test.iterrows(), y_pred):
                true_len = len(D.data['queries'][test_id.values[0]][0]['values'])
                f.write('%s, %d, %d, %0.1f, %0.1f\n'%(test_id.values[0], row['length'], true_len, y_p, true_len - (row['length'] + y_p)))

# %%
for k, v in test_data.items():
    predict_single_batch({k: v}, D)
# Out:
# Predicting Batch 5391:   0%|          | 0/348 [00:00<?, ?it/s]
# Predicting Batch 5391:   0%|          | 1/348 [00:00<00:58,  5.95it/s]
# Predicting Batch 5391:   1%|          | 2/348 [00:00<01:34,  3.65it/s]
# Predicting Batch 5391:   1%|          | 3/348 [00:01<01:49,  3.16it/s]
# Predicting Batch 5391:   1%|          | 4/348 [00:01<02:01,  2.83it/s]
# Predicting Batch 5391:   1%|▏         | 5/348 [00:01<02:08,  2.66it/s]
# Predicting Batch 5391:   2%|▏         | 6/348 [00:02<02:14,  2.54it/s]
# Predicting Batch 5391:   2%|▏         | 7/348 [00:02<02:18,  2.46it/s]
# Predicting Batch 5391:   2%|▏         | 8/348 [00:03<02:24,  2.35it/s]
# Predicting Batch 5391:   3%|▎         | 9/348 [00:03<02:29,  2.27it/s]
# Predicting Batch 5391:   3%|▎         | 10/348 [00:04<02:28,  2.27it/s]
# Predicting Batch 5391:   3%|▎         | 11/348 [00:04<02:26,  2.30it/s]
# Predicting Batch 5391:   3%|▎         | 12/348 [00:05<02:26,  2.30it/s]
# Predicting Batch 5391:   4%|▎         | 13/348 [00:05<02:24,  2.32it/s]
# Predicting Batch 5391:   4%|▍         | 14/348 [00:05<02:24,  2.30it/s]
# Predicting Batch 5391:   4%|▍         | 15/348 [00:06<02:23,  2.31it/s]
# Predicting Batch 5391:   5%|▍         | 16/348 [00:06<02:20,  2.36it/s]
# Predicting Batch 5391:   5%|▍         | 17/348 [00:07<02:21,  2.34it/s]
# Predicting Batch 5391:   5%|▌         | 18/348 [00:07<02:20,  2.36it/s]
# Predicting Batch 5391:   5%|▌         | 19/348 [00:08<02:19,  2.35it/s]
# Predicting Batch 5391:   6%|▌         | 20/348 [00:08<02:18,  2.37it/s]
# Predicting Batch 5391:   6%|▌         | 21/348 [00:08<02:18,  2.36it/s]
# Predicting Batch 5391:   6%|▋         | 22/348 [00:09<02:18,  2.35it/s]
# Predicting Batch 5391:   7%|▋         | 23/348 [00:09<02:18,  2.34it/s]
# Predicting Batch 5391:   7%|▋         | 24/348 [00:10<02:18,  2.34it/s]
# Predicting Batch 5391:   7%|▋         | 25/348 [00:10<02:17,  2.35it/s]
# Predicting Batch 5391:   7%|▋         | 26/348 [00:11<02:17,  2.35it/s]
# Predicting Batch 5391:   8%|▊         | 27/348 [00:11<02:14,  2.38it/s]
# Predicting Batch 5391:   8%|▊         | 28/348 [00:11<02:14,  2.38it/s]
# Predicting Batch 5391:   8%|▊         | 29/348 [00:12<02:12,  2.42it/s]
# Predicting Batch 5391:   9%|▊         | 30/348 [00:12<02:10,  2.44it/s]
# Predicting Batch 5391:   9%|▉         | 31/348 [00:13<02:09,  2.46it/s]
# Predicting Batch 5391:   9%|▉         | 32/348 [00:13<02:09,  2.45it/s]
# Predicting Batch 5391:   9%|▉         | 33/348 [00:13<02:11,  2.40it/s]
# Predicting Batch 5391:  10%|▉         | 34/348 [00:14<02:10,  2.40it/s]
# Predicting Batch 5391:  10%|█         | 35/348 [00:14<02:10,  2.40it/s]
# Predicting Batch 5391:  10%|█         | 36/348 [00:15<02:09,  2.41it/s]
# Predicting Batch 5391:  11%|█         | 37/348 [00:15<02:07,  2.43it/s]
# Predicting Batch 5391:  11%|█         | 38/348 [00:15<02:09,  2.40it/s]
# Predicting Batch 5391:  11%|█         | 39/348 [00:16<02:07,  2.42it/s]
# Predicting Batch 5391:  11%|█▏        | 40/348 [00:16<02:06,  2.44it/s]
# Predicting Batch 5391:  12%|█▏        | 41/348 [00:17<02:07,  2.41it/s]
# Predicting Batch 5391:  12%|█▏        | 42/348 [00:17<02:10,  2.35it/s]
# Predicting Batch 5391:  12%|█▏        | 43/348 [00:18<02:11,  2.32it/s]
# Predicting Batch 5391:  13%|█▎        | 44/348 [00:18<02:09,  2.35it/s]
# Predicting Batch 5391:  13%|█▎        | 45/348 [00:18<02:08,  2.37it/s]
# Predicting Batch 5391:  13%|█▎        | 46/348 [00:19<02:06,  2.38it/s]
# Predicting Batch 5391:  14%|█▎        | 47/348 [00:19<02:08,  2.34it/s]
# Predicting Batch 5391:  14%|█▍        | 48/348 [00:20<02:07,  2.35it/s]
# Predicting Batch 5391:  14%|█▍        | 49/348 [00:20<02:05,  2.38it/s]
# Predicting Batch 5391:  14%|█▍        | 50/348 [00:21<02:04,  2.40it/s]
# Predicting Batch 5391:  15%|█▍        | 51/348 [00:21<02:01,  2.44it/s]
# Predicting Batch 5391:  15%|█▍        | 52/348 [00:21<02:02,  2.42it/s]
# Predicting Batch 5391:  15%|█▌        | 53/348 [00:22<02:00,  2.44it/s]
# Predicting Batch 5391:  16%|█▌        | 54/348 [00:22<02:00,  2.43it/s]
# Predicting Batch 5391:  16%|█▌        | 55/348 [00:23<02:01,  2.41it/s]
# Predicting Batch 5391:  16%|█▌        | 56/348 [00:23<01:59,  2.44it/s]
# Predicting Batch 5391:  16%|█▋        | 57/348 [00:23<01:59,  2.44it/s]
# Predicting Batch 5391:  17%|█▋        | 58/348 [00:24<01:58,  2.44it/s]
# Predicting Batch 5391:  17%|█▋        | 59/348 [00:24<01:58,  2.43it/s]
# Predicting Batch 5391:  17%|█▋        | 60/348 [00:25<01:58,  2.43it/s]
# Predicting Batch 5391:  18%|█▊        | 61/348 [00:25<02:01,  2.36it/s]
# Predicting Batch 5391:  18%|█▊        | 62/348 [00:26<02:00,  2.37it/s]
# Predicting Batch 5391:  18%|█▊        | 63/348 [00:26<02:02,  2.34it/s]
# Predicting Batch 5391:  18%|█▊        | 64/348 [00:26<02:00,  2.35it/s]
# Predicting Batch 5391:  19%|█▊        | 65/348 [00:27<02:00,  2.35it/s]
# Predicting Batch 5391:  19%|█▉        | 66/348 [00:27<01:59,  2.35it/s]
# Predicting Batch 5391:  19%|█▉        | 67/348 [00:28<01:57,  2.39it/s]
# Predicting Batch 5391:  20%|█▉        | 68/348 [00:28<01:55,  2.43it/s]
# Predicting Batch 5391:  20%|█▉        | 69/348 [00:28<01:55,  2.42it/s]
# Predicting Batch 5391:  20%|██        | 70/348 [00:29<01:53,  2.46it/s]
# Predicting Batch 5391:  20%|██        | 71/348 [00:29<01:51,  2.48it/s]
# Predicting Batch 5391:  21%|██        | 72/348 [00:30<01:50,  2.49it/s]
# Predicting Batch 5391:  21%|██        | 73/348 [00:30<01:51,  2.46it/s]
# Predicting Batch 5391:  21%|██▏       | 74/348 [00:30<01:51,  2.47it/s]
# Predicting Batch 5391:  22%|██▏       | 75/348 [00:31<01:50,  2.46it/s]
# Predicting Batch 5391:  22%|██▏       | 76/348 [00:31<01:51,  2.44it/s]
# Predicting Batch 5391:  22%|██▏       | 77/348 [00:32<01:51,  2.43it/s]
# Predicting Batch 5391:  22%|██▏       | 78/348 [00:32<01:50,  2.45it/s]
# Predicting Batch 5391:  23%|██▎       | 79/348 [00:32<01:49,  2.46it/s]
# Predicting Batch 5391:  23%|██▎       | 80/348 [00:33<01:49,  2.45it/s]
# Predicting Batch 5391:  23%|██▎       | 81/348 [00:33<01:47,  2.48it/s]
# Predicting Batch 5391:  24%|██▎       | 82/348 [00:34<01:46,  2.50it/s]
# Predicting Batch 5391:  24%|██▍       | 83/348 [00:34<01:45,  2.52it/s]
# Predicting Batch 5391:  24%|██▍       | 84/348 [00:34<01:46,  2.48it/s]
# Predicting Batch 5391:  24%|██▍       | 85/348 [00:35<01:48,  2.43it/s]
# Predicting Batch 5391:  25%|██▍       | 86/348 [00:35<01:48,  2.42it/s]
# Predicting Batch 5391:  25%|██▌       | 87/348 [00:36<01:48,  2.41it/s]
# Predicting Batch 5391:  25%|██▌       | 88/348 [00:36<01:47,  2.43it/s]
# Predicting Batch 5391:  26%|██▌       | 89/348 [00:37<01:45,  2.45it/s]
# Predicting Batch 5391:  26%|██▌       | 90/348 [00:37<01:44,  2.46it/s]
# Predicting Batch 5391:  26%|██▌       | 91/348 [00:37<01:43,  2.47it/s]
# Predicting Batch 5391:  26%|██▋       | 92/348 [00:38<01:43,  2.48it/s]
# Predicting Batch 5391:  27%|██▋       | 93/348 [00:38<01:42,  2.48it/s]
# Predicting Batch 5391:  27%|██▋       | 94/348 [00:39<01:41,  2.50it/s]
# Predicting Batch 5391:  27%|██▋       | 95/348 [00:39<01:39,  2.53it/s]
# Predicting Batch 5391:  28%|██▊       | 96/348 [00:39<01:39,  2.55it/s]
# Predicting Batch 5391:  28%|██▊       | 97/348 [00:40<01:37,  2.58it/s]
# Predicting Batch 5391:  28%|██▊       | 98/348 [00:40<01:36,  2.60it/s]
# Predicting Batch 5391:  28%|██▊       | 99/348 [00:40<01:34,  2.64it/s]
# Predicting Batch 5391:  29%|██▊       | 100/348 [00:41<01:34,  2.63it/s]
# Predicting Batch 5391:  29%|██▉       | 101/348 [00:41<01:32,  2.68it/s]
# Predicting Batch 5391:  29%|██▉       | 102/348 [00:42<01:32,  2.65it/s]
# Predicting Batch 5391:  30%|██▉       | 103/348 [00:42<01:31,  2.69it/s]
# Predicting Batch 5391:  30%|██▉       | 104/348 [00:42<01:30,  2.71it/s]
# Predicting Batch 5391:  30%|███       | 105/348 [00:43<01:31,  2.65it/s]
# Predicting Batch 5391:  30%|███       | 106/348 [00:43<01:29,  2.70it/s]
# Predicting Batch 5391:  31%|███       | 107/348 [00:43<01:28,  2.74it/s]
# Predicting Batch 5391:  31%|███       | 108/348 [00:44<01:27,  2.74it/s]
# Predicting Batch 5391:  31%|███▏      | 109/348 [00:44<01:26,  2.75it/s]
# Predicting Batch 5391:  32%|███▏      | 110/348 [00:44<01:26,  2.76it/s]
# Predicting Batch 5391:  32%|███▏      | 111/348 [00:45<01:26,  2.75it/s]
# Predicting Batch 5391:  32%|███▏      | 112/348 [00:45<01:25,  2.76it/s]
# Predicting Batch 5391:  32%|███▏      | 113/348 [00:46<01:25,  2.75it/s]
# Predicting Batch 5391:  33%|███▎      | 114/348 [00:46<01:25,  2.74it/s]
# Predicting Batch 5391:  33%|███▎      | 115/348 [00:46<01:23,  2.78it/s]
# Predicting Batch 5391:  33%|███▎      | 116/348 [00:47<01:23,  2.78it/s]
# Predicting Batch 5391:  34%|███▎      | 117/348 [00:47<01:22,  2.82it/s]
# Predicting Batch 5391:  34%|███▍      | 118/348 [00:47<01:22,  2.80it/s]
# Predicting Batch 5391:  34%|███▍      | 119/348 [00:48<01:20,  2.84it/s]
# Predicting Batch 5391:  34%|███▍      | 120/348 [00:48<01:20,  2.84it/s]
# Predicting Batch 5391:  35%|███▍      | 121/348 [00:48<01:19,  2.85it/s]
# Predicting Batch 5391:  35%|███▌      | 122/348 [00:49<01:19,  2.86it/s]
# Predicting Batch 5391:  35%|███▌      | 123/348 [00:49<01:18,  2.86it/s]
# Predicting Batch 5391:  36%|███▌      | 124/348 [00:49<01:18,  2.85it/s]
# Predicting Batch 5391:  36%|███▌      | 125/348 [00:50<01:18,  2.85it/s]
# Predicting Batch 5391:  36%|███▌      | 126/348 [00:50<01:18,  2.82it/s]
# Predicting Batch 5391:  36%|███▋      | 127/348 [00:51<01:19,  2.77it/s]
# Predicting Batch 5391:  37%|███▋      | 128/348 [00:51<01:18,  2.79it/s]
# Predicting Batch 5391:  37%|███▋      | 129/348 [00:51<01:20,  2.73it/s]
# Predicting Batch 5391:  37%|███▋      | 130/348 [00:52<01:18,  2.77it/s]
# Predicting Batch 5391:  38%|███▊      | 131/348 [00:52<01:17,  2.81it/s]
# Predicting Batch 5391:  38%|███▊      | 132/348 [00:52<01:14,  2.89it/s]
# Predicting Batch 5391:  38%|███▊      | 133/348 [00:53<01:13,  2.91it/s]
# Predicting Batch 5391:  39%|███▊      | 134/348 [00:53<01:12,  2.94it/s]
# Predicting Batch 5391:  39%|███▉      | 135/348 [00:53<01:11,  2.97it/s]
# Predicting Batch 5391:  39%|███▉      | 136/348 [00:54<01:10,  3.02it/s]
# Predicting Batch 5391:  39%|███▉      | 137/348 [00:54<01:10,  2.98it/s]
# Predicting Batch 5391:  40%|███▉      | 138/348 [00:54<01:09,  3.01it/s]
# Predicting Batch 5391:  40%|███▉      | 139/348 [00:55<01:09,  3.02it/s]
# Predicting Batch 5391:  40%|████      | 140/348 [00:55<01:08,  3.04it/s]
# Predicting Batch 5391:  41%|████      | 141/348 [00:55<01:09,  2.97it/s]
# Predicting Batch 5391:  41%|████      | 142/348 [00:56<01:09,  2.98it/s]
# Predicting Batch 5391:  41%|████      | 143/348 [00:56<01:08,  2.98it/s]
# Predicting Batch 5391:  41%|████▏     | 144/348 [00:56<01:09,  2.95it/s]
# Predicting Batch 5391:  42%|████▏     | 145/348 [00:57<01:09,  2.93it/s]
# Predicting Batch 5391:  42%|████▏     | 146/348 [00:57<01:08,  2.94it/s]
# Predicting Batch 5391:  42%|████▏     | 147/348 [00:57<01:09,  2.88it/s]
# Predicting Batch 5391:  43%|████▎     | 148/348 [00:58<01:09,  2.87it/s]
# Predicting Batch 5391:  43%|████▎     | 149/348 [00:58<01:11,  2.78it/s]
# Predicting Batch 5391:  43%|████▎     | 150/348 [00:58<01:11,  2.76it/s]
# Predicting Batch 5391:  43%|████▎     | 151/348 [00:59<01:24,  2.33it/s]
# Predicting Batch 5391:  44%|████▎     | 152/348 [00:59<01:19,  2.48it/s]
# Predicting Batch 5391:  44%|████▍     | 153/348 [01:00<01:16,  2.56it/s]
# Predicting Batch 5391:  44%|████▍     | 154/348 [01:00<01:14,  2.61it/s]
# Predicting Batch 5391:  45%|████▍     | 155/348 [01:01<01:19,  2.43it/s]
# Predicting Batch 5391:  45%|████▍     | 156/348 [01:01<01:14,  2.56it/s]
# Predicting Batch 5391:  45%|████▌     | 157/348 [01:01<01:12,  2.65it/s]
# Predicting Batch 5391:  45%|████▌     | 158/348 [01:02<01:08,  2.79it/s]
# Predicting Batch 5391:  46%|████▌     | 159/348 [01:02<01:05,  2.87it/s]
# Predicting Batch 5391:  46%|████▌     | 160/348 [01:02<01:04,  2.93it/s]
# Predicting Batch 5391:  46%|████▋     | 161/348 [01:03<01:02,  2.99it/s]
# Predicting Batch 5391:  47%|████▋     | 162/348 [01:03<01:01,  3.03it/s]
# Predicting Batch 5391:  47%|████▋     | 163/348 [01:03<01:00,  3.06it/s]
# Predicting Batch 5391:  47%|████▋     | 164/348 [01:04<00:59,  3.08it/s]
# Predicting Batch 5391:  47%|████▋     | 165/348 [01:04<00:58,  3.10it/s]
# Predicting Batch 5391:  48%|████▊     | 166/348 [01:04<00:57,  3.15it/s]
# Predicting Batch 5391:  48%|████▊     | 167/348 [01:04<00:57,  3.17it/s]
# Predicting Batch 5391:  48%|████▊     | 168/348 [01:05<00:56,  3.21it/s]
# Predicting Batch 5391:  49%|████▊     | 169/348 [01:05<00:55,  3.23it/s]
# Predicting Batch 5391:  49%|████▉     | 170/348 [01:05<00:54,  3.27it/s]
# Predicting Batch 5391:  49%|████▉     | 171/348 [01:06<00:54,  3.27it/s]
# Predicting Batch 5391:  49%|████▉     | 172/348 [01:06<00:54,  3.22it/s]
# Predicting Batch 5391:  50%|████▉     | 173/348 [01:06<00:54,  3.23it/s]
# Predicting Batch 5391:  50%|█████     | 174/348 [01:07<00:53,  3.27it/s]
# Predicting Batch 5391:  50%|█████     | 175/348 [01:07<00:53,  3.25it/s]
# Predicting Batch 5391:  51%|█████     | 176/348 [01:07<00:52,  3.27it/s]
# Predicting Batch 5391:  51%|█████     | 177/348 [01:08<00:52,  3.26it/s]
# Predicting Batch 5391:  51%|█████     | 178/348 [01:08<00:50,  3.35it/s]
# Predicting Batch 5391:  51%|█████▏    | 179/348 [01:08<00:51,  3.30it/s]
# Predicting Batch 5391:  52%|█████▏    | 180/348 [01:08<00:50,  3.35it/s]
# Predicting Batch 5391:  52%|█████▏    | 181/348 [01:09<00:49,  3.40it/s]
# Predicting Batch 5391:  52%|█████▏    | 182/348 [01:09<00:48,  3.42it/s]
# Predicting Batch 5391:  53%|█████▎    | 183/348 [01:09<00:46,  3.54it/s]
# Predicting Batch 5391:  53%|█████▎    | 184/348 [01:09<00:45,  3.59it/s]
# Predicting Batch 5391:  53%|█████▎    | 185/348 [01:10<00:44,  3.63it/s]
# Predicting Batch 5391:  53%|█████▎    | 186/348 [01:10<00:45,  3.60it/s]
# Predicting Batch 5391:  54%|█████▎    | 187/348 [01:10<00:44,  3.62it/s]
# Predicting Batch 5391:  54%|█████▍    | 188/348 [01:11<00:44,  3.57it/s]
# Predicting Batch 5391:  54%|█████▍    | 189/348 [01:11<00:45,  3.52it/s]
# Predicting Batch 5391:  55%|█████▍    | 190/348 [01:11<00:45,  3.51it/s]
# Predicting Batch 5391:  55%|█████▍    | 191/348 [01:11<00:43,  3.61it/s]
# Predicting Batch 5391:  55%|█████▌    | 192/348 [01:12<00:41,  3.72it/s]
# Predicting Batch 5391:  55%|█████▌    | 193/348 [01:12<00:41,  3.76it/s]
# Predicting Batch 5391:  56%|█████▌    | 194/348 [01:12<00:41,  3.70it/s]
# Predicting Batch 5391:  56%|█████▌    | 195/348 [01:13<00:41,  3.66it/s]
# Predicting Batch 5391:  56%|█████▋    | 196/348 [01:13<00:41,  3.68it/s]
# Predicting Batch 5391:  57%|█████▋    | 197/348 [01:13<00:40,  3.74it/s]
# Predicting Batch 5391:  57%|█████▋    | 198/348 [01:13<00:40,  3.73it/s]
# Predicting Batch 5391:  57%|█████▋    | 199/348 [01:14<00:41,  3.63it/s]
# Predicting Batch 5391:  57%|█████▋    | 200/348 [01:14<00:39,  3.72it/s]
# Predicting Batch 5391:  58%|█████▊    | 201/348 [01:14<00:39,  3.76it/s]
# Predicting Batch 5391:  58%|█████▊    | 202/348 [01:14<00:39,  3.71it/s]
# Predicting Batch 5391:  58%|█████▊    | 203/348 [01:15<00:37,  3.87it/s]
# Predicting Batch 5391:  59%|█████▊    | 204/348 [01:15<00:36,  3.92it/s]
# Predicting Batch 5391:  59%|█████▉    | 205/348 [01:15<00:36,  3.97it/s]
# Predicting Batch 5391:  59%|█████▉    | 206/348 [01:15<00:36,  3.93it/s]
# Predicting Batch 5391:  59%|█████▉    | 207/348 [01:16<00:36,  3.88it/s]
# Predicting Batch 5391:  60%|█████▉    | 208/348 [01:16<00:36,  3.84it/s]
# Predicting Batch 5391:  60%|██████    | 209/348 [01:16<00:35,  3.87it/s]
# Predicting Batch 5391:  60%|██████    | 210/348 [01:16<00:35,  3.90it/s]
# Predicting Batch 5391:  61%|██████    | 211/348 [01:17<00:38,  3.58it/s]
# Predicting Batch 5391:  61%|██████    | 212/348 [01:17<00:36,  3.71it/s]
# Predicting Batch 5391:  61%|██████    | 213/348 [01:17<00:35,  3.76it/s]
# Predicting Batch 5391:  61%|██████▏   | 214/348 [01:17<00:33,  3.94it/s]
# Predicting Batch 5391:  62%|██████▏   | 215/348 [01:18<00:33,  3.98it/s]
# Predicting Batch 5391:  62%|██████▏   | 216/348 [01:18<00:33,  3.98it/s]
# Predicting Batch 5391:  62%|██████▏   | 217/348 [01:18<00:34,  3.80it/s]
# Predicting Batch 5391:  63%|██████▎   | 218/348 [01:19<00:34,  3.74it/s]
# Predicting Batch 5391:  63%|██████▎   | 219/348 [01:19<00:34,  3.75it/s]
# Predicting Batch 5391:  63%|██████▎   | 220/348 [01:19<00:35,  3.63it/s]
# Predicting Batch 5391:  64%|██████▎   | 221/348 [01:19<00:38,  3.34it/s]
# Predicting Batch 5391:  64%|██████▍   | 222/348 [01:20<00:37,  3.38it/s]
# Predicting Batch 5391:  64%|██████▍   | 223/348 [01:20<00:37,  3.29it/s]
# Predicting Batch 5391:  64%|██████▍   | 224/348 [01:20<00:37,  3.32it/s]
# Predicting Batch 5391:  65%|██████▍   | 225/348 [01:21<00:37,  3.25it/s]
# Predicting Batch 5391:  65%|██████▍   | 226/348 [01:21<00:40,  3.02it/s]
# Predicting Batch 5391:  65%|██████▌   | 227/348 [01:21<00:35,  3.36it/s]
# Predicting Batch 5391:  66%|██████▌   | 228/348 [01:22<00:35,  3.39it/s]
# Predicting Batch 5391:  66%|██████▌   | 229/348 [01:22<00:33,  3.50it/s]
# Predicting Batch 5391:  66%|██████▌   | 230/348 [01:22<00:32,  3.60it/s]
# Predicting Batch 5391:  66%|██████▋   | 231/348 [01:22<00:31,  3.68it/s]
# Predicting Batch 5391:  67%|██████▋   | 232/348 [01:23<00:30,  3.85it/s]
# Predicting Batch 5391:  67%|██████▋   | 233/348 [01:23<00:31,  3.67it/s]
# Predicting Batch 5391:  67%|██████▋   | 234/348 [01:23<00:30,  3.73it/s]
# Predicting Batch 5391:  68%|██████▊   | 235/348 [01:23<00:30,  3.70it/s]
# Predicting Batch 5391:  68%|██████▊   | 236/348 [01:24<00:29,  3.80it/s]
# Predicting Batch 5391:  68%|██████▊   | 237/348 [01:24<00:28,  3.90it/s]
# Predicting Batch 5391:  68%|██████▊   | 238/348 [01:24<00:26,  4.17it/s]
# Predicting Batch 5391:  69%|██████▊   | 239/348 [01:24<00:25,  4.28it/s]
# Predicting Batch 5391:  69%|██████▉   | 240/348 [01:25<00:24,  4.36it/s]
# Predicting Batch 5391:  69%|██████▉   | 241/348 [01:25<00:24,  4.37it/s]
# Predicting Batch 5391:  70%|██████▉   | 242/348 [01:25<00:24,  4.26it/s]
# Predicting Batch 5391:  70%|██████▉   | 243/348 [01:25<00:25,  4.19it/s]
# Predicting Batch 5391:  70%|███████   | 244/348 [01:26<00:24,  4.28it/s]
# Predicting Batch 5391:  70%|███████   | 245/348 [01:26<00:24,  4.22it/s]
# Predicting Batch 5391:  71%|███████   | 246/348 [01:26<00:25,  4.02it/s]
# Predicting Batch 5391:  71%|███████   | 247/348 [01:26<00:24,  4.08it/s]
# Predicting Batch 5391:  71%|███████▏  | 248/348 [01:27<00:24,  4.07it/s]
# Predicting Batch 5391:  72%|███████▏  | 249/348 [01:27<00:22,  4.40it/s]
# Predicting Batch 5391:  72%|███████▏  | 250/348 [01:27<00:21,  4.53it/s]
# Predicting Batch 5391:  72%|███████▏  | 251/348 [01:27<00:23,  4.12it/s]
# Predicting Batch 5391:  72%|███████▏  | 252/348 [01:27<00:22,  4.36it/s]
# Predicting Batch 5391:  73%|███████▎  | 253/348 [01:28<00:20,  4.72it/s]
# Predicting Batch 5391:  73%|███████▎  | 254/348 [01:28<00:20,  4.53it/s]
# Predicting Batch 5391:  73%|███████▎  | 255/348 [01:28<00:19,  4.74it/s]
# Predicting Batch 5391:  74%|███████▎  | 256/348 [01:28<00:19,  4.76it/s]
# Predicting Batch 5391:  74%|███████▍  | 257/348 [01:28<00:18,  4.89it/s]
# Predicting Batch 5391:  74%|███████▍  | 258/348 [01:29<00:16,  5.37it/s]
# Predicting Batch 5391:  74%|███████▍  | 259/348 [01:29<00:16,  5.49it/s]
# Predicting Batch 5391:  75%|███████▍  | 260/348 [01:29<00:14,  5.96it/s]
# Predicting Batch 5391:  75%|███████▌  | 261/348 [01:29<00:13,  6.30it/s]
# Predicting Batch 5391:  75%|███████▌  | 262/348 [01:29<00:12,  6.62it/s]
# Predicting Batch 5391:  76%|███████▌  | 263/348 [01:29<00:13,  6.52it/s]
# Predicting Batch 5391:  76%|███████▌  | 264/348 [01:29<00:12,  6.79it/s]
# Predicting Batch 5391:  76%|███████▌  | 265/348 [01:30<00:12,  6.88it/s]
# Predicting Batch 5391:  76%|███████▋  | 266/348 [01:30<00:11,  7.06it/s]
# Predicting Batch 5391:  77%|███████▋  | 267/348 [01:30<00:12,  6.74it/s]
# Predicting Batch 5391:  77%|███████▋  | 268/348 [01:30<00:11,  6.73it/s]
# Predicting Batch 5391:  77%|███████▋  | 269/348 [01:30<00:12,  6.55it/s]
# Predicting Batch 5391:  78%|███████▊  | 270/348 [01:30<00:15,  5.11it/s]
# Predicting Batch 5391:  78%|███████▊  | 271/348 [01:31<00:13,  5.54it/s]
# Predicting Batch 5391:  78%|███████▊  | 272/348 [01:31<00:13,  5.73it/s]
# Predicting Batch 5391:  78%|███████▊  | 273/348 [01:31<00:12,  6.10it/s]
# Predicting Batch 5391:  79%|███████▊  | 274/348 [01:31<00:11,  6.31it/s]
# Predicting Batch 5391:  79%|███████▉  | 275/348 [01:31<00:11,  6.41it/s]
# Predicting Batch 5391:  79%|███████▉  | 276/348 [01:31<00:11,  6.47it/s]
# Predicting Batch 5391:  80%|███████▉  | 277/348 [01:31<00:10,  6.55it/s]
# Predicting Batch 5391:  80%|███████▉  | 278/348 [01:32<00:10,  6.63it/s]
# Predicting Batch 5391:  80%|████████  | 279/348 [01:32<00:10,  6.87it/s]
# Predicting Batch 5391:  80%|████████  | 280/348 [01:32<00:10,  6.79it/s]
# Predicting Batch 5391:  81%|████████  | 281/348 [01:32<00:09,  6.71it/s]
# Predicting Batch 5391:  81%|████████  | 282/348 [01:32<00:10,  6.39it/s]
# Predicting Batch 5391:  81%|████████▏ | 283/348 [01:32<00:11,  5.79it/s]
# Predicting Batch 5391:  82%|████████▏ | 284/348 [01:33<00:10,  5.92it/s]
# Predicting Batch 5391:  82%|████████▏ | 285/348 [01:33<00:11,  5.67it/s]
# Predicting Batch 5391:  82%|████████▏ | 286/348 [01:33<00:10,  6.04it/s]
# Predicting Batch 5391:  82%|████████▏ | 287/348 [01:33<00:10,  6.06it/s]
# Predicting Batch 5391:  83%|████████▎ | 288/348 [01:33<00:10,  5.90it/s]
# Predicting Batch 5391:  83%|████████▎ | 289/348 [01:33<00:10,  5.56it/s]
# Predicting Batch 5391:  83%|████████▎ | 290/348 [01:34<00:10,  5.61it/s]
# Predicting Batch 5391:  84%|████████▍ | 292/348 [01:34<00:08,  6.56it/s]
# Predicting Batch 5391:  85%|████████▍ | 295/348 [01:34<00:06,  7.76it/s]
# Predicting Batch 5391:  85%|████████▌ | 296/348 [01:34<00:07,  7.09it/s]
# Predicting Batch 5391:  85%|████████▌ | 297/348 [01:34<00:07,  6.64it/s]
# Predicting Batch 5391:  86%|████████▌ | 298/348 [01:35<00:07,  6.62it/s]
# Predicting Batch 5391:  86%|████████▌ | 299/348 [01:35<00:07,  6.24it/s]
# Predicting Batch 5391:  86%|████████▌ | 300/348 [01:35<00:07,  6.31it/s]
# Predicting Batch 5391:  86%|████████▋ | 301/348 [01:35<00:07,  6.00it/s]
# Predicting Batch 5391:  87%|████████▋ | 302/348 [01:35<00:07,  5.76it/s]
# Predicting Batch 5391:  87%|████████▋ | 303/348 [01:35<00:07,  6.00it/s]
# Predicting Batch 5391:  87%|████████▋ | 304/348 [01:36<00:07,  5.94it/s]
# Predicting Batch 5391:  88%|████████▊ | 305/348 [01:36<00:07,  5.96it/s]
# Predicting Batch 5391:  88%|████████▊ | 306/348 [01:36<00:07,  5.59it/s]
# Predicting Batch 5391:  88%|████████▊ | 307/348 [01:36<00:07,  5.70it/s]
# Predicting Batch 5391:  89%|████████▊ | 308/348 [01:36<00:06,  6.32it/s]
# Predicting Batch 5391:  89%|████████▉ | 309/348 [01:36<00:05,  6.77it/s]
# Predicting Batch 5391:  89%|████████▉ | 310/348 [01:37<00:05,  6.65it/s]
# Predicting Batch 5391:  89%|████████▉ | 311/348 [01:37<00:05,  7.05it/s]
# Predicting Batch 5391:  90%|████████▉ | 312/348 [01:37<00:05,  7.09it/s]
# Predicting Batch 5391:  90%|████████▉ | 313/348 [01:37<00:04,  7.44it/s]
# Predicting Batch 5391:  90%|█████████ | 314/348 [01:37<00:05,  6.22it/s]
# Predicting Batch 5391:  91%|█████████ | 315/348 [01:37<00:05,  5.73it/s]
# Predicting Batch 5391:  91%|█████████ | 316/348 [01:38<00:05,  5.70it/s]
# Predicting Batch 5391:  91%|█████████ | 317/348 [01:38<00:06,  5.06it/s]
# Predicting Batch 5391:  91%|█████████▏| 318/348 [01:38<00:05,  5.06it/s]
# Predicting Batch 5391:  92%|█████████▏| 319/348 [01:38<00:05,  5.07it/s]
# Predicting Batch 5391:  92%|█████████▏| 320/348 [01:38<00:05,  5.22it/s]
# Predicting Batch 5391:  92%|█████████▏| 321/348 [01:39<00:05,  5.07it/s]
# Predicting Batch 5391:  93%|█████████▎| 322/348 [01:39<00:04,  5.21it/s]
# Predicting Batch 5391:  93%|█████████▎| 323/348 [01:39<00:04,  5.23it/s]
# Predicting Batch 5391:  93%|█████████▎| 324/348 [01:39<00:05,  4.64it/s]
# Predicting Batch 5391:  93%|█████████▎| 325/348 [01:39<00:05,  4.41it/s]
# Predicting Batch 5391:  94%|█████████▎| 326/348 [01:40<00:04,  4.46it/s]
# Predicting Batch 5391:  94%|█████████▍| 327/348 [01:40<00:04,  4.75it/s]
# Predicting Batch 5391:  94%|█████████▍| 328/348 [01:40<00:03,  5.10it/s]
# Predicting Batch 5391:  95%|█████████▍| 329/348 [01:40<00:03,  5.27it/s]
# Predicting Batch 5391:  95%|█████████▍| 330/348 [01:40<00:03,  5.24it/s]
# Predicting Batch 5391:  95%|█████████▌| 331/348 [01:41<00:03,  5.53it/s]
# Predicting Batch 5391:  95%|█████████▌| 332/348 [01:41<00:02,  5.47it/s]
# Predicting Batch 5391:  96%|█████████▌| 333/348 [01:41<00:03,  4.88it/s]
# Predicting Batch 5391:  96%|█████████▌| 334/348 [01:41<00:03,  4.59it/s]
# Predicting Batch 5391:  96%|█████████▋| 335/348 [01:41<00:02,  4.99it/s]
# Predicting Batch 5391:  97%|█████████▋| 336/348 [01:42<00:02,  5.06it/s]
# Predicting Batch 5391:  97%|█████████▋| 337/348 [01:42<00:02,  4.81it/s]
# Predicting Batch 5391:  97%|█████████▋| 338/348 [01:42<00:02,  4.47it/s]
# Predicting Batch 5391:  97%|█████████▋| 339/348 [01:42<00:02,  4.28it/s]
# Predicting Batch 5391:  98%|█████████▊| 340/348 [01:43<00:01,  4.09it/s]
# Predicting Batch 5391:  98%|█████████▊| 341/348 [01:43<00:01,  4.03it/s]
# Predicting Batch 5391:  98%|█████████▊| 342/348 [01:43<00:01,  4.00it/s]
# Predicting Batch 5391:  99%|█████████▊| 343/348 [01:43<00:01,  3.99it/s]
# Predicting Batch 5391:  99%|█████████▉| 344/348 [01:44<00:00,  4.05it/s]
# Predicting Batch 5391:  99%|█████████▉| 345/348 [01:44<00:00,  4.02it/s]
# Predicting Batch 5391:  99%|█████████▉| 346/348 [01:44<00:00,  4.15it/s]
# Predicting Batch 5391: 100%|█████████▉| 347/348 [01:44<00:00,  4.14it/s]
# Predicting Batch 5391: 100%|██████████| 348/348 [01:45<00:00,  4.15it/s]

# %%
ag = 10
fig = plt.figure(figsize=(15,5))
tot_df = pd.DataFrame()
for fn in os.listdir('cv_onlineRF/'):
    df = pd.read_csv('cv_onlineRF/%s'%fn, header=None)
    df.drop_duplicates(inplace=True)
    df['mov_pred'] = df[3].rolling(ag).mean().fillna(method='bfill') + df[1]
    df['err'] = abs(df[2] - df['mov_pred'])
    df['remaining'] = df.loc[:,2] - df.loc[:,1]
    tot_df = pd.concat([tot_df, df], axis = 0)
    plt.plot(df['remaining'], df['err'])
plt.hlines(0, xmin = 0, xmax = plt.xlim()[1])
ax = plt.gca()
ax.invert_xaxis()
plt.xlabel('Time remaining (min)')
plt.ylabel('Absolute deviation (min)')
plt.title('Absolute deviation over time per single batch')
plt.show()

# %%
aggr = tot_df.groupby(by=['remaining']).aggregate({'err': 'mean'})
plt.figure(figsize=(15,5))
plt.plot(aggr)
ax = plt.gca()
ax.invert_xaxis()
plt.xlabel('Remaining time (min)')
plt.ylabel('Average absolute deviation (min)')
plt.title('Average absolute deviation over time (%d min aggregation)'%ag)
plt.show()

# %% [markdown]
# ## Random guessing

# %%
def predict_average(batch, D_train):
    test_batch_id = list(batch.keys())[0]
    D = deepcopy(D_train)
    D.add_query(batch)

    D.call_dtw(test_batch_id, step_pattern=step_pattern, n_jobs=1, open_ended=True, all_sub_seq=True)

    df = pd.read_csv('cv_online/%s.csv'%test_batch_id, header=None, index_col=None)
    for (i, j, d) in tqdm(D.data_open_ended['warp_dist'][test_batch_id], desc='Predicting Batch %s'%test_batch_id, leave=False):
        data_x, data_y = deepcopy(generate_dataset_xy(i, j, test_batch_id, D, data))

        train_id = data_x.loc[data_x.index != test_batch_id, :].index
        test_id = data_x.loc[data_x.index == test_batch_id, :].index
        
        preds = list()
        for _id in train_id:
            true_len = len(D.data['queries'][_id][0]['values'])
            map_len = np.mean(data_x.loc[data_x.index == _id, 'length'].values)
            preds.append(true_len - map_len)
        df.loc[df[1] == i, 5] = np.mean(preds) if len(preds) >= 1 else np.nan
    
    df.to_csv('cv_online/%s_avg.csv'%test_batch_id, header=False, index=False)
    return

# %%
for k, v in test_data.items():
    predict_average({k: v}, D)

# %%
ag = 10
fig = plt.figure(figsize=(15,5))
tot_df1 = pd.DataFrame()
for fn in [name for name in os.listdir('cv_online/') if name.split('.')[0].endswith('avg')]:
    df = pd.read_csv('cv_online/%s'%fn, header=None)
    df.drop_duplicates(inplace=True)
    df['mov_pred'] = df[5].rolling(ag).mean().fillna(method='bfill').fillna(method='ffill') + df[1]
    df['err'] = abs(df[2] - df['mov_pred'])
    df['remaining'] = df.loc[:,2] - df.loc[:,1]
    tot_df1 = pd.concat([tot_df1, df], axis = 0)
    plt.plot(df['remaining'], df['err'])
plt.hlines(0, xmin = 0, xmax = plt.xlim()[1])
ax = plt.gca()
ax.invert_xaxis()
plt.xlabel('Time remaining (min)')
plt.ylabel('Absolute deviation (min)')
plt.title('Absolute deviation over time per single batch (naive approach)')
plt.show()

# %%
aggr = tot_df.groupby(by=['remaining']).aggregate({'err': 'mean'})
plt.figure(figsize=(15,5))
plt.plot(aggr, label = 'SA')
ax = plt.gca()
ax.invert_xaxis()

aggr = tot_df1.groupby(by=['remaining']).aggregate({'err': 'mean'})
plt.plot(aggr, label = 'Naive')
#ax = plt.gca()
#ax.invert_xaxis()
plt.xlabel('Remaining time (min)')
plt.ylabel('Average absolute deviation (min)')
plt.title('Average absolute deviation over time (%d min aggregation)'%ag)
plt.legend()
plt.show()

# %%
errs = defaultdict(list)
dftot = pd.DataFrame()
for fn in os.listdir('cv_online/'):
    if not fn.split('.')[0].endswith('avg'):
        fp = 'cv_online/%s'%fn
        df = pd.read_csv(fp, header = None, index_col=None)
        batch_id = str(df[0][0])
        for _id, row in df.iterrows():
            t = row[1]
            lengths = [len(v[0]['values']) for k, v in train_data.items() if k != 'reference' and len(v[0]['values']) > t]
            pred = np.mean(lengths) if lengths else np.nan
            err = row[2] - pred
            row[5] = row[2] -t
            row[6] = err
            errs[batch_id].append((row[2] -t, err))
            dftot = pd.concat([dftot, pd.DataFrame({'r': row[2] -t, 'e': abs(err)}, index=[0])], ignore_index=True, axis=0)

# %%
aggr = tot_df.groupby(by=['remaining']).aggregate({'err': 'mean'})
aggreg = dftot.groupby(by=['r']).aggregate({'e': 'mean'})
plt.plot(aggreg, label = 'Average')
plt.plot(aggr, label = 'SA')
plt.legend()
ax = plt.gca()
ax.invert_xaxis()
plt.show()

# %%
aggr = tot_df.groupby(by=['remaining']).aggregate({'err': 'mean'})
aggreg = dftot.groupby(by=['r']).aggregate({'e': 'mean'})
sd = tot_df.groupby(by=['remaining']).aggregate({'err': np.std})
plt.figure(figsize = (15,5))
plt.plot(aggreg, label = 'Average Guessing', color = '#a2a2a2')
plt.plot(aggr, label = 'DTW+SA+RF', color='#d90000')
plt.plot(aggr+sd, label = 'DTW+SA+RF + 1SD',color='#d90000', alpha = 0.5)
plt.ylabel('Mean Absolute Error (min)', fontsize=14)
plt.xlabel('Time-to-end (min)', fontsize=14)
plt.legend(fontsize=13)
ax = plt.gca()
ax.invert_xaxis()
plt.savefig('2016.png')
plt.show()
