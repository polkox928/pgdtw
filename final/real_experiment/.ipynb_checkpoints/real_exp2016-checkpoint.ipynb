# %%
# imports
import libdtw as lib
from datetime import datetime
import pickle
import matplotlib.pyplot as plt
from matplotlib.dates import date2num
import numpy as np
from collections import defaultdict
from tqdm import tqdm
from copy import copy, deepcopy
import os
from model import *
from IPython.display import clear_output
import pandas as pd
# Out:
# C:\Users\DEPAGRA\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# The first step in the realization of the experiment is to select a meaningful time frame. First we plot the length of all the available batches against the starting date to check for any time trend.

# %%
raw_data = lib.load_data(n_to_keep=1000)
_ = raw_data.pop('reference')
plt.hist([len(v[0]['values']) for k, v in raw_data.items()])
plt.title('Distribution of batch duration')
plt.xlabel('Batch duration (min)')
plt.ylabel('Count')
plt.show()
print("Min duration: %d\nMax duration %d"\
      %(min([len(v[0]['values']) for k, v in raw_data.items()]), max([len(v[0]['values']) for k, v in raw_data.items()])))
# Out:
# Min duration: 146
# Max duration 1661

# %%
fig = plt.figure(figsize=(15,7))
for k, v in raw_data.items():
    plt.plot_date(date2num(datetime.strptime(v[0]['start'], '%Y-%m-%d %H:%M:%S')), len(v[0]['values']), color = '#d90000')
plt.xlabel('Start date', fontsize = 14)
plt.ylabel('Batch duration', fontsize = 14)
plt.title('Batch duration against Start date', fontsize = 16)
plt.xlim((date2num(datetime.strptime('2014-11-01', '%Y-%m-%d')), 
          date2num(datetime.strptime('2017-12-31', '%Y-%m-%d'))))

plt.axvspan(date2num(datetime.strptime('2014-11-01', '%Y-%m-%d')), 
            date2num(datetime.strptime('2014-12-31', '%Y-%m-%d')), 
            color='#d2d2d2', alpha=0.1)

plt.axvspan(date2num(datetime.strptime('2015-01-01', '%Y-%m-%d')), 
            date2num(datetime.strptime('2015-12-31', '%Y-%m-%d')), 
            color='#d2d2d2', alpha=0.5)

plt.axvspan(date2num(datetime.strptime('2016-01-01', '%Y-%m-%d')), 
            date2num(datetime.strptime('2016-12-31', '%Y-%m-%d')), 
            color='#d2d2d2', alpha=0.1)

plt.axvspan(date2num(datetime.strptime('2017-01-01', '%Y-%m-%d')), 
            date2num(datetime.strptime('2017-12-31', '%Y-%m-%d')), 
            color='#d2d2d2', alpha=0.5)
plt.savefig('durVSstart.png')
plt.show()

# %% [markdown]
# The data seems to have a time dependency. This could be useful for the predictive model, but it's unrealistic to use all the data available for the DTW part of the system. Therefore we select only one period, the 2016, and remove the outlier batches: this way DTW will perform better and we will have a wider search space for the step patterns.

# %%
fig, (ax0, ax1) = plt.subplots(1,2, figsize=(15,5), gridspec_kw = {'width_ratios':[3, 1]})
data_2016 = dict((k, v) for k, v in raw_data.items() if datetime.strptime(v[0]['start'][:4], '%Y') == datetime.strptime('2016', '%Y'))
for k, v in data_2016.items():
    ax0.plot_date(date2num(datetime.strptime(v[0]['start'], '%Y-%m-%d %H:%M:%S')), len(v[0]['values']), color = '#000000')
ax0.set_xlabel('Start date')
ax0.set_ylabel('Batch duration')
ax0.set_title('Batch duration against Start date')

box = ax1.boxplot([len(v[0]['values']) for k, v in data_2016.items()])
ax1.set_ylabel('Batch duration')
plt.setp(ax1, xticklabels=['2016'])
plt.show()

upper_cap = box['caps'][1].get_ydata()[0]
print('Upper cap value: %d'%upper_cap)
# Out:
# Upper cap value: 708

# %% [markdown]
# Batches with duration above 708 minutes are considered outliers. We remove them from the dataset.

# %%
data = dict((k,v) for k,v in data_2016.items() if len(v[0]['values']) <= 708)

fig, (ax0, ax1) = plt.subplots(1,2, figsize=(15,5))
for k, v in data.items():
    ax0.plot_date(date2num(datetime.strptime(v[0]['start'], '%Y-%m-%d %H:%M:%S')), len(v[0]['values']), color = '#000000')
ax0.set_xlabel('Start date')
ax0.set_ylabel('Batch duration')
ax0.set_title('Batch duration against Start date')

ax1.hist([len(v[0]['values']) for k, v in data.items()])
ax1.set_xlabel('Batch duration')
ax1.set_ylabel('Count')
ax1.set_title('Distribution of batch duration')
plt.show()

print('Number of batches: %d'%len(data))
# Out:
# Number of batches: 151

# %% [markdown]
# We have 151 batches. We use the first 101 as training set, and the other 50 as test. The IDs are assigned in temporal order, so we can use them as splitting criterion.

# %%
train_size = 101
train_data = dict(sorted(list(data.items()))[:train_size])
raw_test_data = dict(sorted(list(data.items()))[train_size:])
print("Train data: %d batches\nTest data: %d batches"%(len(train_data), len(raw_test_data)))
# Out:
# Train data: 101 batches
# Test data: 50 batches

# %% [markdown]
# We now create the DTW object for the training data, checking the maximum P value allowed for the step pattern. We seelect the batch with the median length as reference one.

# %%
if 'reference' in train_data: _=train_data.pop('reference')
train_data = lib.assign_ref(train_data)
D = lib.Dtw(json_obj=train_data)
print('Number of PVs used : %d'%len(D.pv_names))
# Out:
# Number of PVs used : 33

# %% [markdown]
# Among the 100 queriy batches, only one does not have all the PVs contained in the reference one. We therefore have 1 reference and 99 queries. We have to check if all the test batches have all the necessary PVs.

# %%
pv_ref = D.pv_names
test_data = dict()
for k, v in raw_test_data.items():
    batch = list(filter(lambda x: x['name'] in pv_ref, v))
    if len(batch) == len(pv_ref):
        test_data[k]=batch
print('Number of test batches after filtering for PVs: %d'%len(test_data))
# Out:
# Number of test batches after filtering for PVs: 50

# %% [markdown]
# All of the test batches have the required PVs

# %% [markdown]
# Let's check the maximum P value allowed

# %%
print('Global P max: %d'%D.get_global_p_max())
# Out:
# Global P max: 1

# %% [markdown]
# The maximum allowed value is P = 1. Therefore for the step pattern selection we will consider the step patterns `symmetricP05` and `symmetricP1`, and maybe also `symmetric1` and `symmetric2`.
#
# First step is to optimize the features' weights given this dataset.

# %%
num_queries = D.data['num_queries']
step_pattern = 'symmetric2'
file_path = 'data/optWeights.pickle'
n_jobs=-2
try:
    with open(file_path, 'rb') as f:
        D.data['feat_weights'] = pickle.load(f)
    #print('Initial weights:\n', D.data['feat_weights'])
except OSError as ex:
#    pass
#finally:
    D.optimize_weights(step_pattern, n_steps = 20, file_path = file_path, n_jobs=n_jobs)
    with open(file_path, 'wb') as f:
        pickle.dump(D.data['feat_weights'], f, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# Let's set the variables weights of the original DTW object with the new optimized weights

# %%
sorted(list(D.get_weight_variables().items()), key = lambda x: x[1], reverse=True)
# Out:
# [('ba_TCzWpXo', 3.2231621945076925),
#  ('ba_TCfg3Yxn', 3.221614529955474),
#  ('ba_PLAu1m2', 1.6911678668671668),
#  ('ba_FC3BnZ', 1.3435038209030385),
#  ('ba_TZHx41ABpBbhN', 1.3426510388255273),
#  ('ba_TCyNE8Mdv', 1.3310743700255487),
#  ('ba_TDZV2zDOrmiYP', 1.219830709431491),
#  ('ba_TDZyHMh1UZ', 1.1984956645804208),
#  ('ba_TZWZNzFFdHb', 1.1938101570561284),
#  ('ba_FCGUglDXyPKrnk38', 1.1675047951226567),
#  ('ba_PCLAMr1nuoSiAr', 1.0468981462066496),
#  ('ba_PCSTgdwK3V', 0.9964977921080833),
#  ('ba_PCPUSq5ah', 0.9160370462879545),
#  ('ba_FCDvhG4', 0.8591861915869534),
#  ('ba_TCkwAse0bopy8zp6', 0.8402901972310711),
#  ('ba_TC06nRC', 0.8339192662684214),
#  ('ba_TZv9w2dOu', 0.82387642561287),
#  ('ba_TZIm086h', 0.8026973178251918),
#  ('ba_PCGd0srEZp', 0.7401844519898652),
#  ('ba_TIJSj', 0.7060735054691898),
#  ('ba_ErguU', 0.6884786616870558),
#  ('ba_FQVzNY', 0.6157197009664962),
#  ('ba_FQ2Qyx', 0.6067029303109742),
#  ('ba_FQnZKYLSO02xLf', 0.5937279762873314),
#  ('ba_FIhgSwHD', 0.5923625274413772),
#  ('ba_TrWfpiPrs', 0.5774110301472146),
#  ('ba_SinhbKA', 0.5647529852113228),
#  ('ba_FCobtZJfb5TG', 0.5627732756440307),
#  ('ba_TZNCmUn29mO', 0.5550326173137785),
#  ('ba_PCG6Z9', 0.5466359771507334),
#  ('ba_FQNOJG', 0.5423644115448256),
#  ('ba_FQYXdr6Q0', 0.5420597030694593),
#  ('ba_FmYOrhonkk', 0.5135027153640023)]

# %% [markdown]
# Now it's time to select a step pattern

# %%
print('P max: %d'%D.get_global_p_max())
POSSIBLE_STEP_PATTERNS = ['symmetric2', 'symmetricP05'] + ['symmetricP%s'%p for p in np.arange(1, D.get_global_p_max()+1)]
try:
    with open('stepPattern.pickle', 'rb') as f:
        D = pickle.load(f)
except: pass

RES = defaultdict(list)
for step_pattern in POSSIBLE_STEP_PATTERNS[::-1]:
    #print(step_pattern)
    for _id in tqdm(D.data['queriesID'], desc=step_pattern, leave=False):
        D.call_dtw(_id, step_pattern=step_pattern, n_jobs=-1)

    RES[step_pattern].append(D.avg_time_distortion(step_pattern))
    RES[step_pattern].append(D.avg_distance(step_pattern))

    # pickle D object
with open('stepPattern.pickle', 'wb') as f:
    pickle.dump(D, f, protocol=pickle.HIGHEST_PROTOCOL)

TD = [x[0] for x in RES.values()]
RANGE_TD = min(TD), max(TD)

DIST = [x[1] for x in RES.values()]

RANGE_DIST = min(DIST), max(DIST)

RES_SCALED = defaultdict(list)
for step_pattern in POSSIBLE_STEP_PATTERNS:
    RES_SCALED[step_pattern] = [(RES[step_pattern][0] - RANGE_TD[0])/(RANGE_TD[1]-RANGE_TD[0])]
    RES_SCALED[step_pattern].append((RES[step_pattern][1] - RANGE_DIST[0])/(RANGE_DIST[1]-RANGE_DIST[0]))

DISTORTIONS = [RES_SCALED[step_pattern][0] for step_pattern in POSSIBLE_STEP_PATTERNS]
DISTANCES = [RES_SCALED[step_pattern][1] for step_pattern in POSSIBLE_STEP_PATTERNS]
SCORE = [np.sqrt(x**2 + y**2) for x, y in zip(DISTANCES, DISTORTIONS)]

#print(TD)
#print(DIST)

for step_pattern in POSSIBLE_STEP_PATTERNS:
    score = np.sqrt(RES_SCALED[step_pattern][0]**2 + RES_SCALED[step_pattern][1]**2)
    print('%s Score: %0.5f\tTime Dist: %0.5f/%0.5f\t DTW Dist: %0.5f/%0.5f'%(step_pattern, score, RES[step_pattern][0], 
                                                                             RES_SCALED[step_pattern][0], RES[step_pattern][1], 
                                                                             RES_SCALED[step_pattern][1]))
# Out:
# P max: 1
# symmetric2 Score: 1.00000	Time Dist: 106.14141/1.00000	 DTW Dist: 181.13020/0.00000
# symmetricP05 Score: 0.67495	Time Dist: 86.18182/0.00000	 DTW Dist: 181.27823/0.67495
# symmetricP1 Score: 1.00000	Time Dist: 86.18182/0.00000	 DTW Dist: 181.34951/1.00000

# %%
X = np.arange(1, len(SCORE)+1)

FIG = plt.figure(figsize=(12, 5))
FIG.add_subplot(1, 2, 1)

plt.plot(X, SCORE, '-o', color = '#d90000')
plt.xticks(X, POSSIBLE_STEP_PATTERNS, rotation=0)
plt.ylabel("Alignment SCORE")


FIG.add_subplot(1, 2, 2)
plt.plot(DISTANCES, DISTORTIONS, '-o', color = '#d90000')
plt.xlabel("Scaled distance")
plt.ylabel("Scaled time distortion")

for i in range(len(POSSIBLE_STEP_PATTERNS)):
    plt.annotate(POSSIBLE_STEP_PATTERNS[i][:3]+POSSIBLE_STEP_PATTERNS[i].split('c')[1], xy=(DISTANCES[i], DISTORTIONS[i]), xytext=(4, 4), textcoords='offset pixels')
plt.xlim((-0.05, 1.15))
plt.tight_layout()
plt.show()

# %%
step_pattern = 'symmetricP05'

# %%
try:
    with open('open_ended.pickle', 'rb') as f:
        D = pickle.load(f)
except:
    for _id in tqdm(D.data['queriesID'], desc='Open-ended DTW - Train Set', leave=False):
        D.call_dtw(_id, step_pattern=step_pattern, n_jobs=1, open_ended=True, all_sub_seq=True)

# %%
with open('open_ended.pickle', 'wb') as f:
    pickle.dump(D, f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
def predict_single_batch(batch, D_train):
    test_batch_id = list(batch.keys())[0]
    if '%s.csv'%test_batch_id in os.listdir('cv_onlineRF/'): return
    
    D = deepcopy(D_train)
    D.add_query(batch)
    clear_output()
    D.call_dtw(test_batch_id, step_pattern=step_pattern, n_jobs=1, open_ended=True, all_sub_seq=True)
    
    estimator = Estimator(dtw_obj=D, regressor=RandomForestRegressor())
    for (i, j, d) in tqdm(D.data_open_ended['warp_dist'][test_batch_id], desc='Predicting Batch %s'%test_batch_id):

        data_x, data_y = deepcopy(generate_dataset_xy(i, j, test_batch_id, D, data))

        train_id = data_x.loc[data_x.index != test_batch_id, :].index
        test_id = data_x.loc[data_x.index == test_batch_id, :].index

        train_loc = list()
        for _id in train_id.unique():
            locs = data_x.index.get_loc(_id)
            if type(locs) == slice:
                start, stop = locs.start, locs.stop
                train_loc.extend([[loc] for loc in np.arange(start, stop)])
            elif type(locs) == int or type(locs) == np.int64:
                train_loc.append([locs])
            else: print('\n', locs, type(locs))

        if type(data_x.index.get_loc(test_batch_id)) == slice:
            locs = data_x.index.get_loc(test_batch_id)
            start, stop = locs.start, locs.stop
            test_loc = [[loc] for loc in np.arange(start, stop)]
        elif type(data_x.index.get_loc(test_batch_id)) == int or type(data_x.index.get_loc(test_batch_id)) == np.int64:
            test_loc = [data_x.index.get_loc(test_batch_id)]
        else: print('ERROR 2')

        train_id, test_id, train_loc, test_loc = train_id.unique(), test_id.unique(), train_loc, test_loc
        if len(train_id) < 2:
            continue

        x_train = data_x.loc[train_id, :]

        y_train = np.array(np.concatenate([data_y[idx] for idx in train_loc], axis=0), dtype = [('status', bool), ('time_remaining', 'f8')])

        x_test = data_x.loc[test_id, :]
        y_test_raw = [data_y[idx] for idx in test_loc]

        y_test = np.concatenate(y_test_raw, axis=0) if len(y_test_raw)>1 else y_test_raw
        y_test = np.array(y_test, dtype = [('status', bool), ('time_remaining', 'f8')])

        estimator.fit(x_train, y_train)
        y_pred = estimator.predict(x_test)
        with open('cv_onlineRF/%s.csv'%test_id.values[0], 'a+') as f:
            for (_id, row), y_p in zip(x_test.iterrows(), y_pred):
                true_len = len(D.data['queries'][test_id.values[0]][0]['values'])
                f.write('%s, %d, %d, %0.1f, %0.1f\n'%(test_id.values[0], row['length'], true_len, y_p, true_len - (row['length'] + y_p)))

# %%
for k, v in test_data.items():
    predict_single_batch({k: v}, D)
# Out:
# Predicting Batch 5341:   0%|          | 0/413 [00:00<?, ?it/s]
# Predicting Batch 5341:   0%|          | 1/413 [00:00<01:13,  5.58it/s]
# Predicting Batch 5341:   0%|          | 2/413 [00:00<02:10,  3.15it/s]
# Predicting Batch 5341:   1%|          | 3/413 [00:01<02:38,  2.59it/s]
# Predicting Batch 5341:   1%|          | 4/413 [00:01<02:55,  2.34it/s]
# Predicting Batch 5341:   1%|          | 5/413 [00:02<03:13,  2.11it/s]
# Predicting Batch 5341:   1%|▏         | 6/413 [00:03<03:29,  1.94it/s]
# Predicting Batch 5341:   2%|▏         | 7/413 [00:03<03:32,  1.91it/s]
# Predicting Batch 5341:   2%|▏         | 8/413 [00:04<03:23,  1.99it/s]
# Predicting Batch 5341:   2%|▏         | 9/413 [00:04<03:17,  2.05it/s]
# Predicting Batch 5341:   2%|▏         | 10/413 [00:05<03:21,  2.00it/s]
# Predicting Batch 5341:   3%|▎         | 11/413 [00:05<03:16,  2.04it/s]
# Predicting Batch 5341:   3%|▎         | 12/413 [00:06<03:15,  2.06it/s]
# Predicting Batch 5341:   3%|▎         | 13/413 [00:06<03:24,  1.95it/s]
# Predicting Batch 5341:   3%|▎         | 14/413 [00:07<03:14,  2.05it/s]
# Predicting Batch 5341:   4%|▎         | 15/413 [00:07<03:10,  2.09it/s]
# Predicting Batch 5341:   4%|▍         | 16/413 [00:07<03:09,  2.10it/s]
# Predicting Batch 5341:   4%|▍         | 17/413 [00:08<03:30,  1.88it/s]
# Predicting Batch 5341:   4%|▍         | 18/413 [00:09<03:27,  1.91it/s]
# Predicting Batch 5341:   5%|▍         | 19/413 [00:09<03:17,  1.99it/s]
# Predicting Batch 5341:   5%|▍         | 20/413 [00:10<03:13,  2.04it/s]
# Predicting Batch 5341:   5%|▌         | 21/413 [00:10<03:23,  1.92it/s]
# Predicting Batch 5341:   5%|▌         | 22/413 [00:11<03:18,  1.97it/s]
# Predicting Batch 5341:   6%|▌         | 23/413 [00:11<03:42,  1.75it/s]
# Predicting Batch 5341:   6%|▌         | 24/413 [00:12<03:25,  1.89it/s]
# Predicting Batch 5341:   6%|▌         | 25/413 [00:12<03:28,  1.86it/s]
# Predicting Batch 5341:   6%|▋         | 26/413 [00:13<03:22,  1.91it/s]
# Predicting Batch 5341:   7%|▋         | 27/413 [00:13<03:13,  1.99it/s]
# Predicting Batch 5341:   7%|▋         | 28/413 [00:14<03:13,  1.99it/s]
# Predicting Batch 5341:   7%|▋         | 29/413 [00:14<03:10,  2.02it/s]
# Predicting Batch 5341:   7%|▋         | 30/413 [00:15<03:08,  2.03it/s]
# Predicting Batch 5341:   8%|▊         | 31/413 [00:15<03:11,  2.00it/s]
# Predicting Batch 5341:   8%|▊         | 32/413 [00:16<03:06,  2.04it/s]
# Predicting Batch 5341:   8%|▊         | 33/413 [00:16<03:13,  1.96it/s]
# Predicting Batch 5341:   8%|▊         | 34/413 [00:17<03:08,  2.01it/s]
# Predicting Batch 5341:   8%|▊         | 35/413 [00:17<03:03,  2.06it/s]
# Predicting Batch 5341:   9%|▊         | 36/413 [00:18<03:05,  2.03it/s]
# Predicting Batch 5341:   9%|▉         | 37/413 [00:18<03:08,  2.00it/s]
# Predicting Batch 5341:   9%|▉         | 38/413 [00:19<03:06,  2.01it/s]
# Predicting Batch 5341:   9%|▉         | 39/413 [00:19<02:59,  2.09it/s]
# Predicting Batch 5341:  10%|▉         | 40/413 [00:20<02:53,  2.15it/s]
# Predicting Batch 5341:  10%|▉         | 41/413 [00:20<02:56,  2.11it/s]
# Predicting Batch 5341:  10%|█         | 42/413 [00:21<02:52,  2.15it/s]
# Predicting Batch 5341:  10%|█         | 43/413 [00:21<02:52,  2.15it/s]
# Predicting Batch 5341:  11%|█         | 44/413 [00:21<02:50,  2.16it/s]
# Predicting Batch 5341:  11%|█         | 45/413 [00:22<02:50,  2.16it/s]
# Predicting Batch 5341:  11%|█         | 46/413 [00:22<02:53,  2.12it/s]
# Predicting Batch 5341:  11%|█▏        | 47/413 [00:23<02:51,  2.13it/s]
# Predicting Batch 5341:  12%|█▏        | 48/413 [00:23<02:58,  2.05it/s]
# Predicting Batch 5341:  12%|█▏        | 49/413 [00:24<03:00,  2.01it/s]
# Predicting Batch 5341:  12%|█▏        | 50/413 [00:24<02:56,  2.06it/s]
# Predicting Batch 5341:  12%|█▏        | 51/413 [00:25<02:53,  2.09it/s]
# Predicting Batch 5341:  13%|█▎        | 52/413 [00:25<02:52,  2.09it/s]
# Predicting Batch 5341:  13%|█▎        | 53/413 [00:26<02:47,  2.15it/s]
# Predicting Batch 5341:  13%|█▎        | 54/413 [00:26<02:56,  2.03it/s]
# Predicting Batch 5341:  13%|█▎        | 55/413 [00:27<02:53,  2.06it/s]
# Predicting Batch 5341:  14%|█▎        | 56/413 [00:27<02:49,  2.11it/s]
# Predicting Batch 5341:  14%|█▍        | 57/413 [00:28<03:02,  1.96it/s]
# Predicting Batch 5341:  14%|█▍        | 58/413 [00:28<02:59,  1.97it/s]
# Predicting Batch 5341:  14%|█▍        | 59/413 [00:29<02:54,  2.03it/s]
# Predicting Batch 5341:  15%|█▍        | 60/413 [00:29<02:49,  2.08it/s]
# Predicting Batch 5341:  15%|█▍        | 61/413 [00:30<02:48,  2.09it/s]
# Predicting Batch 5341:  15%|█▌        | 62/413 [00:30<02:51,  2.05it/s]
# Predicting Batch 5341:  15%|█▌        | 63/413 [00:31<02:52,  2.03it/s]
# Predicting Batch 5341:  15%|█▌        | 64/413 [00:31<02:49,  2.06it/s]
# Predicting Batch 5341:  16%|█▌        | 65/413 [00:32<02:46,  2.09it/s]
# Predicting Batch 5341:  16%|█▌        | 66/413 [00:32<02:47,  2.07it/s]
# Predicting Batch 5341:  16%|█▌        | 67/413 [00:33<02:50,  2.02it/s]
# Predicting Batch 5341:  16%|█▋        | 68/413 [00:33<02:43,  2.11it/s]
# Predicting Batch 5341:  17%|█▋        | 69/413 [00:34<02:47,  2.05it/s]
# Predicting Batch 5341:  17%|█▋        | 70/413 [00:34<02:53,  1.98it/s]
# Predicting Batch 5341:  17%|█▋        | 71/413 [00:35<02:46,  2.05it/s]
# Predicting Batch 5341:  17%|█▋        | 72/413 [00:35<02:44,  2.07it/s]
# Predicting Batch 5341:  18%|█▊        | 73/413 [00:35<02:35,  2.19it/s]
# Predicting Batch 5341:  18%|█▊        | 74/413 [00:36<02:31,  2.23it/s]
# Predicting Batch 5341:  18%|█▊        | 75/413 [00:36<02:37,  2.15it/s]
# Predicting Batch 5341:  18%|█▊        | 76/413 [00:37<02:33,  2.20it/s]
# Predicting Batch 5341:  19%|█▊        | 77/413 [00:37<02:31,  2.21it/s]
# Predicting Batch 5341:  19%|█▉        | 78/413 [00:38<02:36,  2.14it/s]
# Predicting Batch 5341:  19%|█▉        | 79/413 [00:38<02:33,  2.17it/s]
# Predicting Batch 5341:  19%|█▉        | 80/413 [00:39<02:34,  2.15it/s]
# Predicting Batch 5341:  20%|█▉        | 81/413 [00:39<02:28,  2.24it/s]
# Predicting Batch 5341:  20%|█▉        | 82/413 [00:40<02:26,  2.25it/s]
# Predicting Batch 5341:  20%|██        | 83/413 [00:40<02:34,  2.14it/s]
# Predicting Batch 5341:  20%|██        | 84/413 [00:40<02:29,  2.20it/s]
# Predicting Batch 5341:  21%|██        | 85/413 [00:41<02:28,  2.21it/s]
# Predicting Batch 5341:  21%|██        | 86/413 [00:41<02:27,  2.22it/s]
# Predicting Batch 5341:  21%|██        | 87/413 [00:42<02:27,  2.22it/s]
# Predicting Batch 5341:  21%|██▏       | 88/413 [00:42<02:37,  2.07it/s]
# Predicting Batch 5341:  22%|██▏       | 89/413 [00:43<02:32,  2.12it/s]
# Predicting Batch 5341:  22%|██▏       | 90/413 [00:43<02:30,  2.15it/s]
# Predicting Batch 5341:  22%|██▏       | 91/413 [00:44<02:26,  2.20it/s]
# Predicting Batch 5341:  22%|██▏       | 92/413 [00:44<02:36,  2.05it/s]
# Predicting Batch 5341:  23%|██▎       | 93/413 [00:45<02:27,  2.17it/s]
# Predicting Batch 5341:  23%|██▎       | 94/413 [00:45<02:22,  2.24it/s]
# Predicting Batch 5341:  23%|██▎       | 95/413 [00:45<02:17,  2.31it/s]
# Predicting Batch 5341:  23%|██▎       | 96/413 [00:46<02:23,  2.21it/s]
# Predicting Batch 5341:  23%|██▎       | 97/413 [00:46<02:20,  2.24it/s]
# Predicting Batch 5341:  24%|██▎       | 98/413 [00:47<02:14,  2.34it/s]
# Predicting Batch 5341:  24%|██▍       | 99/413 [00:47<02:11,  2.38it/s]
# Predicting Batch 5341:  24%|██▍       | 100/413 [00:48<02:10,  2.39it/s]
# Predicting Batch 5341:  24%|██▍       | 101/413 [00:48<02:16,  2.29it/s]
# Predicting Batch 5341:  25%|██▍       | 102/413 [00:49<02:24,  2.16it/s]
# Predicting Batch 5341:  25%|██▍       | 103/413 [00:49<02:20,  2.21it/s]
# Predicting Batch 5341:  25%|██▌       | 104/413 [00:50<02:23,  2.15it/s]
# Predicting Batch 5341:  25%|██▌       | 105/413 [00:50<02:29,  2.07it/s]
# Predicting Batch 5341:  26%|██▌       | 106/413 [00:50<02:21,  2.18it/s]
# Predicting Batch 5341:  26%|██▌       | 107/413 [00:51<02:17,  2.22it/s]
# Predicting Batch 5341:  26%|██▌       | 108/413 [00:51<02:12,  2.30it/s]
# Predicting Batch 5341:  26%|██▋       | 109/413 [00:52<02:08,  2.37it/s]
# Predicting Batch 5341:  27%|██▋       | 110/413 [00:52<02:13,  2.27it/s]
# Predicting Batch 5341:  27%|██▋       | 111/413 [00:53<02:06,  2.38it/s]
# Predicting Batch 5341:  27%|██▋       | 112/413 [00:53<02:03,  2.44it/s]
# Predicting Batch 5341:  27%|██▋       | 113/413 [00:53<02:02,  2.45it/s]
# Predicting Batch 5341:  28%|██▊       | 114/413 [00:54<02:02,  2.45it/s]
# Predicting Batch 5341:  28%|██▊       | 115/413 [00:54<02:05,  2.37it/s]
# Predicting Batch 5341:  28%|██▊       | 116/413 [00:55<02:03,  2.41it/s]
# Predicting Batch 5341:  28%|██▊       | 117/413 [00:55<01:58,  2.49it/s]
# Predicting Batch 5341:  29%|██▊       | 118/413 [00:55<01:55,  2.55it/s]
# Predicting Batch 5341:  29%|██▉       | 119/413 [00:56<01:59,  2.46it/s]
# Predicting Batch 5341:  29%|██▉       | 120/413 [00:56<01:54,  2.55it/s]
# Predicting Batch 5341:  29%|██▉       | 121/413 [00:57<01:54,  2.54it/s]
# Predicting Batch 5341:  30%|██▉       | 122/413 [00:57<01:53,  2.56it/s]
# Predicting Batch 5341:  30%|██▉       | 123/413 [00:57<01:55,  2.51it/s]
# Predicting Batch 5341:  30%|███       | 124/413 [00:58<01:51,  2.58it/s]
# Predicting Batch 5341:  30%|███       | 125/413 [00:58<01:56,  2.47it/s]
# Predicting Batch 5341:  31%|███       | 126/413 [00:59<01:58,  2.42it/s]
# Predicting Batch 5341:  31%|███       | 127/413 [00:59<01:53,  2.51it/s]
# Predicting Batch 5341:  31%|███       | 128/413 [00:59<01:50,  2.59it/s]
# Predicting Batch 5341:  31%|███       | 129/413 [01:00<01:48,  2.62it/s]
# Predicting Batch 5341:  31%|███▏      | 130/413 [01:00<01:54,  2.47it/s]
# Predicting Batch 5341:  32%|███▏      | 131/413 [01:00<01:47,  2.62it/s]
# Predicting Batch 5341:  32%|███▏      | 132/413 [01:01<02:02,  2.29it/s]
# Predicting Batch 5341:  32%|███▏      | 133/413 [01:01<02:00,  2.33it/s]
# Predicting Batch 5341:  32%|███▏      | 134/413 [01:02<01:54,  2.44it/s]
# Predicting Batch 5341:  33%|███▎      | 135/413 [01:02<01:57,  2.36it/s]
# Predicting Batch 5341:  33%|███▎      | 136/413 [01:03<01:51,  2.49it/s]
# Predicting Batch 5341:  33%|███▎      | 137/413 [01:03<01:51,  2.47it/s]
# Predicting Batch 5341:  33%|███▎      | 138/413 [01:03<01:47,  2.56it/s]
# Predicting Batch 5341:  34%|███▎      | 139/413 [01:04<01:51,  2.46it/s]
# Predicting Batch 5341:  34%|███▍      | 140/413 [01:04<01:46,  2.57it/s]
# Predicting Batch 5341:  34%|███▍      | 141/413 [01:05<01:47,  2.54it/s]
# Predicting Batch 5341:  34%|███▍      | 142/413 [01:05<01:47,  2.51it/s]
# Predicting Batch 5341:  35%|███▍      | 143/413 [01:05<01:50,  2.44it/s]
# Predicting Batch 5341:  35%|███▍      | 144/413 [01:06<01:53,  2.37it/s]
# Predicting Batch 5341:  35%|███▌      | 145/413 [01:06<01:54,  2.34it/s]
# Predicting Batch 5341:  35%|███▌      | 146/413 [01:07<01:57,  2.27it/s]
# Predicting Batch 5341:  36%|███▌      | 147/413 [01:07<01:51,  2.39it/s]
# Predicting Batch 5341:  36%|███▌      | 148/413 [01:07<01:46,  2.49it/s]
# Predicting Batch 5341:  36%|███▌      | 149/413 [01:08<01:52,  2.34it/s]
# Predicting Batch 5341:  36%|███▋      | 150/413 [01:08<01:46,  2.48it/s]
# Predicting Batch 5341:  37%|███▋      | 151/413 [01:09<01:43,  2.52it/s]
# Predicting Batch 5341:  37%|███▋      | 152/413 [01:09<01:40,  2.60it/s]
# Predicting Batch 5341:  37%|███▋      | 153/413 [01:09<01:43,  2.51it/s]
# Predicting Batch 5341:  37%|███▋      | 154/413 [01:10<01:38,  2.63it/s]
# Predicting Batch 5341:  38%|███▊      | 155/413 [01:10<01:41,  2.53it/s]
# Predicting Batch 5341:  38%|███▊      | 156/413 [01:11<01:41,  2.54it/s]
# Predicting Batch 5341:  38%|███▊      | 157/413 [01:11<01:37,  2.62it/s]
# Predicting Batch 5341:  38%|███▊      | 158/413 [01:11<01:38,  2.58it/s]
# Predicting Batch 5341:  38%|███▊      | 159/413 [01:12<01:39,  2.56it/s]
# Predicting Batch 5341:  39%|███▊      | 160/413 [01:12<01:39,  2.55it/s]
# Predicting Batch 5341:  39%|███▉      | 161/413 [01:13<01:35,  2.63it/s]
# Predicting Batch 5341:  39%|███▉      | 162/413 [01:13<01:37,  2.59it/s]
# Predicting Batch 5341:  39%|███▉      | 163/413 [01:13<01:35,  2.61it/s]
# Predicting Batch 5341:  40%|███▉      | 164/413 [01:14<01:39,  2.50it/s]
# Predicting Batch 5341:  40%|███▉      | 165/413 [01:14<01:46,  2.34it/s]
# Predicting Batch 5341:  40%|████      | 166/413 [01:15<01:48,  2.27it/s]
# Predicting Batch 5341:  40%|████      | 167/413 [01:15<01:47,  2.30it/s]
# Predicting Batch 5341:  41%|████      | 168/413 [01:16<01:45,  2.33it/s]
# Predicting Batch 5341:  41%|████      | 169/413 [01:16<01:43,  2.35it/s]
# Predicting Batch 5341:  41%|████      | 170/413 [01:16<01:35,  2.54it/s]
# Predicting Batch 5341:  41%|████▏     | 171/413 [01:17<01:36,  2.51it/s]
# Predicting Batch 5341:  42%|████▏     | 172/413 [01:17<01:34,  2.56it/s]
# Predicting Batch 5341:  42%|████▏     | 173/413 [01:17<01:31,  2.63it/s]
# Predicting Batch 5341:  42%|████▏     | 174/413 [01:18<01:26,  2.78it/s]
# Predicting Batch 5341:  42%|████▏     | 175/413 [01:18<01:28,  2.70it/s]
# Predicting Batch 5341:  43%|████▎     | 176/413 [01:18<01:25,  2.77it/s]
# Predicting Batch 5341:  43%|████▎     | 177/413 [01:19<01:25,  2.76it/s]
# Predicting Batch 5341:  43%|████▎     | 178/413 [01:19<01:19,  2.94it/s]
# Predicting Batch 5341:  43%|████▎     | 179/413 [01:19<01:18,  2.99it/s]
# Predicting Batch 5341:  44%|████▎     | 180/413 [01:20<01:16,  3.06it/s]
# Predicting Batch 5341:  44%|████▍     | 181/413 [01:20<01:22,  2.81it/s]
# Predicting Batch 5341:  44%|████▍     | 182/413 [01:21<01:20,  2.88it/s]
# Predicting Batch 5341:  44%|████▍     | 183/413 [01:21<01:18,  2.92it/s]
# Predicting Batch 5341:  45%|████▍     | 184/413 [01:21<01:18,  2.90it/s]
# Predicting Batch 5341:  45%|████▍     | 185/413 [01:22<01:16,  2.98it/s]
# Predicting Batch 5341:  45%|████▌     | 186/413 [01:22<01:14,  3.05it/s]
# Predicting Batch 5341:  45%|████▌     | 187/413 [01:22<01:15,  2.98it/s]
# Predicting Batch 5341:  46%|████▌     | 188/413 [01:23<01:20,  2.78it/s]
# Predicting Batch 5341:  46%|████▌     | 189/413 [01:23<01:16,  2.95it/s]
# Predicting Batch 5341:  46%|████▌     | 190/413 [01:23<01:13,  3.05it/s]
# Predicting Batch 5341:  46%|████▌     | 191/413 [01:23<01:08,  3.23it/s]
# Predicting Batch 5341:  46%|████▋     | 192/413 [01:24<01:05,  3.37it/s]
# Predicting Batch 5341:  47%|████▋     | 193/413 [01:24<01:09,  3.18it/s]
# Predicting Batch 5341:  47%|████▋     | 194/413 [01:24<01:07,  3.25it/s]
# Predicting Batch 5341:  47%|████▋     | 195/413 [01:25<01:07,  3.22it/s]
# Predicting Batch 5341:  47%|████▋     | 196/413 [01:25<01:09,  3.11it/s]
# Predicting Batch 5341:  48%|████▊     | 197/413 [01:25<01:14,  2.90it/s]
# Predicting Batch 5341:  48%|████▊     | 198/413 [01:26<01:12,  2.96it/s]
# Predicting Batch 5341:  48%|████▊     | 199/413 [01:26<01:17,  2.78it/s]
# Predicting Batch 5341:  48%|████▊     | 200/413 [01:26<01:12,  2.95it/s]
# Predicting Batch 5341:  49%|████▊     | 201/413 [01:27<01:09,  3.07it/s]
# Predicting Batch 5341:  49%|████▉     | 202/413 [01:27<01:07,  3.14it/s]
# Predicting Batch 5341:  49%|████▉     | 203/413 [01:27<01:03,  3.30it/s]
# Predicting Batch 5341:  49%|████▉     | 204/413 [01:28<01:04,  3.25it/s]
# Predicting Batch 5341:  50%|████▉     | 205/413 [01:28<01:01,  3.38it/s]
# Predicting Batch 5341:  50%|████▉     | 206/413 [01:28<01:04,  3.19it/s]
# Predicting Batch 5341:  50%|█████     | 207/413 [01:29<01:07,  3.06it/s]
# Predicting Batch 5341:  50%|█████     | 208/413 [01:29<01:03,  3.23it/s]
# Predicting Batch 5341:  51%|█████     | 209/413 [01:29<00:58,  3.48it/s]
# Predicting Batch 5341:  51%|█████     | 210/413 [01:29<00:55,  3.63it/s]
# Predicting Batch 5341:  51%|█████     | 211/413 [01:30<00:55,  3.61it/s]
# Predicting Batch 5341:  51%|█████▏    | 212/413 [01:30<00:58,  3.46it/s]
# Predicting Batch 5341:  52%|█████▏    | 213/413 [01:30<00:57,  3.47it/s]
# Predicting Batch 5341:  52%|█████▏    | 214/413 [01:31<00:57,  3.48it/s]
# Predicting Batch 5341:  52%|█████▏    | 215/413 [01:31<00:55,  3.56it/s]
# Predicting Batch 5341:  52%|█████▏    | 216/413 [01:31<00:56,  3.47it/s]
# Predicting Batch 5341:  53%|█████▎    | 217/413 [01:31<00:55,  3.55it/s]
# Predicting Batch 5341:  53%|█████▎    | 218/413 [01:32<00:54,  3.57it/s]
# Predicting Batch 5341:  53%|█████▎    | 219/413 [01:32<00:59,  3.25it/s]
# Predicting Batch 5341:  53%|█████▎    | 220/413 [01:32<00:55,  3.50it/s]
# Predicting Batch 5341:  54%|█████▎    | 221/413 [01:33<00:52,  3.65it/s]
# Predicting Batch 5341:  54%|█████▍    | 222/413 [01:33<00:51,  3.74it/s]
# Predicting Batch 5341:  54%|█████▍    | 223/413 [01:33<00:49,  3.83it/s]
# Predicting Batch 5341:  54%|█████▍    | 224/413 [01:33<00:54,  3.47it/s]
# Predicting Batch 5341:  54%|█████▍    | 225/413 [01:34<00:53,  3.52it/s]
# Predicting Batch 5341:  55%|█████▍    | 226/413 [01:34<00:55,  3.39it/s]
# Predicting Batch 5341:  55%|█████▍    | 227/413 [01:34<00:53,  3.46it/s]
# Predicting Batch 5341:  55%|█████▌    | 228/413 [01:35<00:53,  3.44it/s]
# Predicting Batch 5341:  55%|█████▌    | 229/413 [01:35<00:53,  3.46it/s]
# Predicting Batch 5341:  56%|█████▌    | 230/413 [01:35<00:52,  3.49it/s]
# Predicting Batch 5341:  56%|█████▌    | 231/413 [01:35<00:53,  3.43it/s]
# Predicting Batch 5341:  56%|█████▌    | 232/413 [01:36<00:50,  3.59it/s]
# Predicting Batch 5341:  56%|█████▋    | 233/413 [01:36<00:53,  3.36it/s]
# Predicting Batch 5341:  57%|█████▋    | 234/413 [01:36<00:51,  3.47it/s]
# Predicting Batch 5341:  57%|█████▋    | 235/413 [01:37<00:49,  3.63it/s]
# Predicting Batch 5341:  57%|█████▋    | 236/413 [01:37<00:49,  3.56it/s]
# Predicting Batch 5341:  57%|█████▋    | 237/413 [01:37<00:48,  3.60it/s]
# Predicting Batch 5341:  58%|█████▊    | 238/413 [01:37<00:49,  3.51it/s]
# Predicting Batch 5341:  58%|█████▊    | 239/413 [01:38<00:48,  3.58it/s]
# Predicting Batch 5341:  58%|█████▊    | 240/413 [01:38<00:46,  3.75it/s]
# Predicting Batch 5341:  58%|█████▊    | 241/413 [01:38<00:48,  3.57it/s]
# Predicting Batch 5341:  59%|█████▊    | 242/413 [01:38<00:48,  3.56it/s]
# Predicting Batch 5341:  59%|█████▉    | 243/413 [01:39<00:46,  3.68it/s]
# Predicting Batch 5341:  59%|█████▉    | 244/413 [01:39<00:47,  3.57it/s]
# Predicting Batch 5341:  59%|█████▉    | 245/413 [01:39<00:47,  3.50it/s]
# Predicting Batch 5341:  60%|█████▉    | 246/413 [01:40<00:46,  3.57it/s]
# Predicting Batch 5341:  60%|█████▉    | 247/413 [01:40<00:44,  3.75it/s]
# Predicting Batch 5341:  60%|██████    | 248/413 [01:40<00:44,  3.69it/s]
# Predicting Batch 5341:  60%|██████    | 249/413 [01:40<00:48,  3.37it/s]
# Predicting Batch 5341:  61%|██████    | 250/413 [01:41<00:46,  3.49it/s]
# Predicting Batch 5341:  61%|██████    | 251/413 [01:41<00:45,  3.57it/s]
# Predicting Batch 5341:  61%|██████    | 252/413 [01:41<00:45,  3.53it/s]
# Predicting Batch 5341:  61%|██████▏   | 253/413 [01:41<00:43,  3.70it/s]
# Predicting Batch 5341:  62%|██████▏   | 254/413 [01:42<00:41,  3.85it/s]
# Predicting Batch 5341:  62%|██████▏   | 255/413 [01:42<00:37,  4.21it/s]
# Predicting Batch 5341:  62%|██████▏   | 256/413 [01:42<00:37,  4.14it/s]
# Predicting Batch 5341:  62%|██████▏   | 257/413 [01:42<00:36,  4.24it/s]
# Predicting Batch 5341:  62%|██████▏   | 258/413 [01:43<00:35,  4.31it/s]
# Predicting Batch 5341:  63%|██████▎   | 259/413 [01:43<00:35,  4.31it/s]
# Predicting Batch 5341:  63%|██████▎   | 260/413 [01:43<00:36,  4.20it/s]
# Predicting Batch 5341:  63%|██████▎   | 261/413 [01:43<00:36,  4.22it/s]
# Predicting Batch 5341:  63%|██████▎   | 262/413 [01:44<00:36,  4.08it/s]
# Predicting Batch 5341:  64%|██████▎   | 263/413 [01:44<00:34,  4.38it/s]
# Predicting Batch 5341:  64%|██████▍   | 264/413 [01:44<00:37,  3.96it/s]
# Predicting Batch 5341:  64%|██████▍   | 265/413 [01:44<00:36,  4.11it/s]
# Predicting Batch 5341:  64%|██████▍   | 266/413 [01:45<00:34,  4.24it/s]
# Predicting Batch 5341:  65%|██████▍   | 267/413 [01:45<00:32,  4.44it/s]
# Predicting Batch 5341:  65%|██████▍   | 268/413 [01:45<00:32,  4.51it/s]
# Predicting Batch 5341:  65%|██████▌   | 269/413 [01:45<00:35,  4.08it/s]
# Predicting Batch 5341:  65%|██████▌   | 270/413 [01:45<00:35,  4.06it/s]
# Predicting Batch 5341:  66%|██████▌   | 271/413 [01:46<00:37,  3.82it/s]
# Predicting Batch 5341:  66%|██████▌   | 272/413 [01:46<00:33,  4.17it/s]
# Predicting Batch 5341:  66%|██████▌   | 273/413 [01:46<00:34,  4.09it/s]
# Predicting Batch 5341:  66%|██████▋   | 274/413 [01:46<00:33,  4.10it/s]
# Predicting Batch 5341:  67%|██████▋   | 275/413 [01:47<00:33,  4.15it/s]
# Predicting Batch 5341:  67%|██████▋   | 276/413 [01:47<00:32,  4.25it/s]
# Predicting Batch 5341:  67%|██████▋   | 277/413 [01:47<00:29,  4.57it/s]
# Predicting Batch 5341:  67%|██████▋   | 278/413 [01:47<00:33,  4.07it/s]
# Predicting Batch 5341:  68%|██████▊   | 279/413 [01:48<00:34,  3.87it/s]
# Predicting Batch 5341:  68%|██████▊   | 280/413 [01:48<00:32,  4.03it/s]
# Predicting Batch 5341:  68%|██████▊   | 281/413 [01:48<00:32,  4.03it/s]
# Predicting Batch 5341:  68%|██████▊   | 282/413 [01:48<00:32,  4.04it/s]
# Predicting Batch 5341:  69%|██████▊   | 283/413 [01:49<00:30,  4.20it/s]
# Predicting Batch 5341:  69%|██████▉   | 284/413 [01:49<00:29,  4.31it/s]
# Predicting Batch 5341:  69%|██████▉   | 285/413 [01:49<00:26,  4.80it/s]
# Predicting Batch 5341:  69%|██████▉   | 286/413 [01:49<00:28,  4.42it/s]
# Predicting Batch 5341:  69%|██████▉   | 287/413 [01:50<00:30,  4.12it/s]
# Predicting Batch 5341:  70%|██████▉   | 288/413 [01:50<00:31,  4.03it/s]
# Predicting Batch 5341:  70%|██████▉   | 289/413 [01:50<00:31,  3.92it/s]
# Predicting Batch 5341:  70%|███████   | 290/413 [01:50<00:27,  4.45it/s]
# Predicting Batch 5341:  70%|███████   | 291/413 [01:50<00:26,  4.54it/s]
# Predicting Batch 5341:  71%|███████   | 292/413 [01:51<00:25,  4.77it/s]
# Predicting Batch 5341:  71%|███████   | 293/413 [01:51<00:23,  5.06it/s]
# Predicting Batch 5341:  71%|███████   | 294/413 [01:51<00:23,  5.09it/s]
# Predicting Batch 5341:  71%|███████▏  | 295/413 [01:51<00:26,  4.50it/s]
# Predicting Batch 5341:  72%|███████▏  | 296/413 [01:52<00:26,  4.46it/s]
# Predicting Batch 5341:  72%|███████▏  | 297/413 [01:52<00:28,  4.03it/s]
# Predicting Batch 5341:  72%|███████▏  | 298/413 [01:52<00:28,  4.06it/s]
# Predicting Batch 5341:  72%|███████▏  | 299/413 [01:52<00:25,  4.50it/s]
# Predicting Batch 5341:  73%|███████▎  | 300/413 [01:52<00:24,  4.58it/s]
# Predicting Batch 5341:  73%|███████▎  | 301/413 [01:53<00:23,  4.78it/s]
# Predicting Batch 5341:  73%|███████▎  | 302/413 [01:53<00:21,  5.06it/s]
# Predicting Batch 5341:  73%|███████▎  | 303/413 [01:53<00:22,  4.81it/s]
# Predicting Batch 5341:  74%|███████▎  | 304/413 [01:53<00:28,  3.85it/s]
# Predicting Batch 5341:  74%|███████▍  | 305/413 [01:54<00:28,  3.84it/s]
# Predicting Batch 5341:  74%|███████▍  | 306/413 [01:54<00:32,  3.33it/s]
# Predicting Batch 5341:  74%|███████▍  | 307/413 [01:54<00:28,  3.72it/s]
# Predicting Batch 5341:  75%|███████▍  | 308/413 [01:54<00:26,  4.03it/s]
# Predicting Batch 5341:  75%|███████▍  | 309/413 [01:55<00:23,  4.35it/s]

# %%
ag = 10
fig = plt.figure(figsize=(15,5))
tot_df = pd.DataFrame()
for fn in os.listdir('cv_onlineRF/'):
    df = pd.read_csv('cv_onlineRF/%s'%fn, header=None)
    df.drop_duplicates(inplace=True)
    df['mov_pred'] = df[3].rolling(ag).mean().fillna(method='bfill') + df[1]
    df['err'] = abs(df[2] - df['mov_pred'])
    df['remaining'] = df.loc[:,2] - df.loc[:,1]
    tot_df = pd.concat([tot_df, df], axis = 0)
    plt.plot(df['remaining'], df['err'])
plt.hlines(0, xmin = 0, xmax = plt.xlim()[1])
ax = plt.gca()
ax.invert_xaxis()
plt.xlabel('Time remaining (min)')
plt.ylabel('Absolute deviation (min)')
plt.title('Absolute deviation over time per single batch')
plt.show()

# %%
aggr = tot_df.groupby(by=['remaining']).aggregate({'err': 'mean'})
plt.figure(figsize=(15,5))
plt.plot(aggr)
ax = plt.gca()
ax.invert_xaxis()
plt.xlabel('Remaining time (min)')
plt.ylabel('Average absolute deviation (min)')
plt.title('Average absolute deviation over time (%d min aggregation)'%ag)
plt.show()

# %% [markdown]
# ## Random guessing

# %%
def predict_average(batch, D_train):
    test_batch_id = list(batch.keys())[0]
    D = deepcopy(D_train)
    D.add_query(batch)

    D.call_dtw(test_batch_id, step_pattern=step_pattern, n_jobs=1, open_ended=True, all_sub_seq=True)

    df = pd.read_csv('cv_online/%s.csv'%test_batch_id, header=None, index_col=None)
    for (i, j, d) in tqdm(D.data_open_ended['warp_dist'][test_batch_id], desc='Predicting Batch %s'%test_batch_id, leave=False):
        data_x, data_y = deepcopy(generate_dataset_xy(i, j, test_batch_id, D, data))

        train_id = data_x.loc[data_x.index != test_batch_id, :].index
        test_id = data_x.loc[data_x.index == test_batch_id, :].index
        
        preds = list()
        for _id in train_id:
            true_len = len(D.data['queries'][_id][0]['values'])
            map_len = np.mean(data_x.loc[data_x.index == _id, 'length'].values)
            preds.append(true_len - map_len)
        df.loc[df[1] == i, 5] = np.mean(preds) if len(preds) >= 1 else np.nan
    
    df.to_csv('cv_online/%s_avg.csv'%test_batch_id, header=False, index=False)
    return

# %%
for k, v in test_data.items():
    predict_average({k: v}, D)

# %%
ag = 10
fig = plt.figure(figsize=(15,5))
tot_df1 = pd.DataFrame()
for fn in [name for name in os.listdir('cv_online/') if name.split('.')[0].endswith('avg')]:
    df = pd.read_csv('cv_online/%s'%fn, header=None)
    df.drop_duplicates(inplace=True)
    df['mov_pred'] = df[5].rolling(ag).mean().fillna(method='bfill').fillna(method='ffill') + df[1]
    df['err'] = abs(df[2] - df['mov_pred'])
    df['remaining'] = df.loc[:,2] - df.loc[:,1]
    tot_df1 = pd.concat([tot_df1, df], axis = 0)
    plt.plot(df['remaining'], df['err'])
plt.hlines(0, xmin = 0, xmax = plt.xlim()[1])
ax = plt.gca()
ax.invert_xaxis()
plt.xlabel('Time remaining (min)')
plt.ylabel('Absolute deviation (min)')
plt.title('Absolute deviation over time per single batch (naive approach)')
plt.show()

# %%
aggr = tot_df.groupby(by=['remaining']).aggregate({'err': 'mean'})
plt.figure(figsize=(15,5))
plt.plot(aggr, label = 'SA')
ax = plt.gca()
ax.invert_xaxis()

aggr = tot_df1.groupby(by=['remaining']).aggregate({'err': 'mean'})
plt.plot(aggr, label = 'Naive')
#ax = plt.gca()
#ax.invert_xaxis()
plt.xlabel('Remaining time (min)')
plt.ylabel('Average absolute deviation (min)')
plt.title('Average absolute deviation over time (%d min aggregation)'%ag)
plt.legend()
plt.show()

# %%
errs = defaultdict(list)
dftot = pd.DataFrame()
for fn in os.listdir('cv_online/'):
    if not fn.split('.')[0].endswith('avg'):
        fp = 'cv_online/%s'%fn
        df = pd.read_csv(fp, header = None, index_col=None)
        batch_id = str(df[0][0])
        for _id, row in df.iterrows():
            t = row[1]
            lengths = [len(v[0]['values']) for k, v in train_data.items() if k != 'reference' and len(v[0]['values']) > t]
            pred = np.mean(lengths) if lengths else np.nan
            err = row[2] - pred
            row[5] = row[2] -t
            row[6] = err
            errs[batch_id].append((row[2] -t, err))
            dftot = pd.concat([dftot, pd.DataFrame({'r': row[2] -t, 'e': abs(err)}, index=[0])], ignore_index=True, axis=0)
            
    

aggr = tot_df.groupby(by=['remaining']).aggregate({'err': 'mean'})
aggreg = dftot.groupby(by=['r']).aggregate({'e': 'mean'})
plt.plot(aggreg, label = 'Average')
plt.plot(aggr, label = 'SA')
plt.legend()
ax = plt.gca()
ax.invert_xaxis()
plt.show()
